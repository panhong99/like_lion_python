# %%
import tensorflow as tf
import numpy as np

# %%
data = np.loadtxt("/Users/panhong/Desktop/coding_study/Likelion_KDT/Jupyter_notebook/data-03-diabetes.csv" , delimiter = ",")

x_data0 = np.array([x_row[0] for x_row in data])
x_data1 = np.array([x_row[1] for x_row in data])
x_data2 = np.array([x_row[2] for x_row in data])
x_data3 = np.array([x_row[3] for x_row in data])
x_data4 = np.array([x_row[4] for x_row in data])
x_data5 = np.array([x_row[5] for x_row in data])
x_data6 = np.array([x_row[6] for x_row in data])
x_data7 = np.array([x_row[7] for x_row in data])
y_data = np.array([y_row[8] for y_row in data])
# Out:
# [ 0.         0.         0.        -0.777778  -0.602837   0.
#  -0.791962   0.         0.283688   0.         0.         0.
#   0.         1.         0.        -0.456265   0.        -0.803783
#  -0.77305   -0.444444   0.         0.         0.        -0.728132
#   0.        -0.669031  -0.739953   0.         0.        -0.420804
#  -0.87234    0.         0.        -0.546099   0.         0.
#   0.        -0.510638  -0.834515   0.         0.        -0.432624
#   0.         0.         0.         0.         0.         0.
#  -0.806147  -0.914894  -0.945626  -0.29078   -0.191489   0.
#  -0.281324  -0.739953   0.        -0.664303   0.         0.
#   0.        -0.6974     0.         0.         0.         0.
#  -0.910165  -0.763593  -0.787234  -0.669031   0.        -0.361702
#   0.         0.         0.         0.         0.         0.
#   0.         0.        -0.832151   0.         0.        -0.704492
#   0.        -0.832151  -0.739953   0.         0.        -0.583924
# ...
