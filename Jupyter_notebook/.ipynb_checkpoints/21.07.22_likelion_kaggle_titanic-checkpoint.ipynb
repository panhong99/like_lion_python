# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import seaborn as sns
import re
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.models import  Sequential
from tensorflow.keras.layers import Dense 
from tensorflow.keras.callbacks import ModelCheckpoint , EarlyStopping
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

train_data = pd.read_csv("/Users/panhong/Desktop/coding_study/Likelion_KDT/Jupyter_notebook/csv_file/train.csv")

test_data = pd.read_csv("/Users/panhong/Desktop/coding_study/Likelion_KDT/Jupyter_notebook/csv_file/test.csv")

# 먼저 결측치 확인 
train_data.isna().sum()

# 결측치를 해당 컬럼의 평균으로 대체
train_data["Age"] = train_data["Age"].fillna(train_data["Age"].mean())
test_data["Age"] = test_data["Age"].fillna(test_data["Age"].mean())

# train_data["Age"]

# 라벨인코더를 위해서 data에서 pop
name = train_data.pop("Name")
sex = train_data.pop("Sex")
embarked = train_data.pop("Embarked")
survived_cloen = train_data.pop("Survived")

# ticket같은 경우도 문자열과 혼합이 되어있기때문에 
# 마지막 숫자만 끌어와서 np.array로 변형시켜주고 
# data에 추가시킨다.
ticket_cloen = train_data.pop("Ticket")
ticket_cloen = list(ticket_cloen)

ticket_save = []

for i in ticket_cloen:
    ticket_save.append(i[-1])
save_ticket = np.array(ticket_save)

# cabin같은 경우는 결측치도 많고 슬라이싱도 해주어야 해서 
# fillna함수로 결측치를 삭제시켜주고 첫글자만 슬라이싱을 해줌
# 그리고서 라벨인코딩 후 data에 추가

cabin_save = train_data.pop("Cabin")
cabin_save = cabin_save.fillna(method = "pad")
cabin_save = cabin_save.fillna("C85")

save_cabin = []

for i in range(len(cabin_save)):
    save_cabin.append(cabin_save[i][:1])
cabin_cloen = np.array(save_cabin)

# 라벨 인코딩 시작 
e1 = LabelEncoder()
e1.fit(name)
name = e1.transform(name)

e2 = LabelEncoder()
e2.fit(sex)
sex = e2.transform(sex)

e3 = LabelEncoder()
e3.fit(embarked)
embarked = e3.transform(embarked)

e4 = LabelEncoder()
e4.fit(cabin_cloen)
cabin = e4.transform(cabin_cloen)

e5 = LabelEncoder()
e5.fit(save_ticket)
ticket = e5.transform(save_ticket)

# 인코딩을 마치고 data에 설정
train_data["Ticket"] = ticket
train_data["Cabin"] = cabin
train_data["Name"] = name
train_data["Sex"] = sex
train_data["Embarked"] = embarked
train_data["Survived"] = survived_cloen

# 데이터의 밸류들만 가져와서 dataset 변수에 저장 
# 아래 구문부터는 너무나도 익숙한 케라스의 기본 모델이기때문에
# 자세한 설명은 하지않겠음
dataset = train_data.values
x_data = dataset[: , :11]
y = dataset[: , 11]

y_data = tf.keras.utils.to_categorical(y)

# %%
train_data = pd.read_csv("/Users/panhong/Desktop/coding_study/Likelion_KDT/Jupyter_notebook/csv_file/train.csv")

test_data = pd.read_csv("/Users/panhong/Desktop/coding_study/Likelion_KDT/Jupyter_notebook/csv_file/test.csv")

# 먼저 결측치 확인 
# train_data.isna().sum()

# 결측치를 해당 컬럼의 평균으로 대체
# train_data["Age"] = train_data["Age"].fillna(train_data["Age"].mean())
test_data["Age"] = test_data["Age"].fillna(test_data["Age"].mean())
# train_data["Age"]

# 라벨인코더를 위해서 data에서 pop
name_test = test_data.pop("Name")
sex_test = test_data.pop("Sex")
embarked_test = test_data.pop("Embarked")
# survived_cloen_test = test_data.pop("Survived")

ticket_cloen_test = test_data.pop("Ticket")
ticket_cloen_test = list(ticket_cloen_test)

ticket_save_test = []

for i in ticket_cloen_test:
    ticket_save_test.append(i[-1])
save_ticket_test = np.array(ticket_save_test)

# cabin같은 경우는 결측치도 많고 슬라이싱도 해주어야 해서 
# fillna함수로 결측치를 삭제시켜주고 첫글자만 슬라이싱을 해줌
# 그리고서 라벨인코딩 후 data에 추가

cabin_save_test = test_data.pop("Cabin")
cabin_save_test = cabin_save_test.fillna(method = "pad")
cabin_save_test = cabin_save_test.fillna("C85")

save_cabin_test = []

for i in range(len(cabin_save_test)):
    save_cabin_test.append(cabin_save_test[i][:1])
cabin_cloen_test = np.array(save_cabin_test)

e1 = LabelEncoder()
e1.fit(name_test)
name_test_data = e1.transform(name_test)

e2 = LabelEncoder()
e2.fit(sex_test)
sex_test = e2.transform(sex_test)

e3 = LabelEncoder()
e3.fit(embarked_test)
embarked_test = e3.transform(embarked_test)

e4_test = LabelEncoder()
e4_test.fit(cabin_cloen_test)
cabin_test = e4_test.transform(cabin_cloen_test)

e5_test = LabelEncoder()
e5_test.fit(save_ticket_test)
ticket_test = e5.transform(save_ticket_test)

test_data["Ticket"] = ticket_test
test_data["Cabin"] = cabin_test
test_data["Name"] = name_test_data
test_data["Sex"] = sex_test
test_data["Embarked"] = embarked_test
# test_data["Survived"] = survived_cloen_test

# 결측치 삭제
test_data = test_data.dropna()

dataset_test = test_data.values
x_test = dataset_test[: , :11]

# %%
model = Sequential()
model.add(Dense(30 , input_dim = 11 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(2 , activation = "softmax"))

model.compile(loss = "categorical_crossentropy" , optimizer = optimizers.Adam(lr = 0.001) , metrics = ["accuracy"])

model_dir = "./model_titanic/"
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
modelpath = "./model_titanic/{epoch:02d}-{accuracy:.4f}.hdf5"

checkpoint = ModelCheckpoint(filepath = modelpath , mointor = "val_loss" , verbose = 1 , save_best_only = True)

earlystopping = EarlyStopping(monitor = "val_loss" , patience = 100)

model.fit(x_data , y_data , epochs = 2000 , verbose = 1 , validation_split = 0.33 , callbacks = [checkpoint , earlystopping])

model.summary()

y_prediction = model.predict(x_test).flatten()

for i in range(10):
    prediction = y_prediction
    print("실제값 : {:.3f}".format(prediction))
print("\nAccuracy %.4f" %(model.evaluate(x_data ,y_data)[1]))
# Out:
# /Users/panhong/miniforge3/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.7142 - accuracy: 0.5906 - val_loss: 0.6764 - val_accuracy: 0.6339
#
# Epoch 00001: val_loss improved from inf to 0.67643, saving model to ./model_titanic/01-0.5906.hdf5
# Epoch 2/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6883 - accuracy: 0.5956 - val_loss: 0.6275 - val_accuracy: 0.6746
#
# Epoch 00002: val_loss improved from 0.67643 to 0.62749, saving model to ./model_titanic/02-0.5956.hdf5
# Epoch 3/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6573 - accuracy: 0.6409 - val_loss: 0.6495 - val_accuracy: 0.6305
#
# Epoch 00003: val_loss did not improve from 0.62749
# Epoch 4/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6867 - accuracy: 0.5839 - val_loss: 0.6218 - val_accuracy: 0.6475
#
# Epoch 00004: val_loss improved from 0.62749 to 0.62182, saving model to ./model_titanic/04-0.5839.hdf5
# Epoch 5/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6878 - accuracy: 0.5872 - val_loss: 0.6355 - val_accuracy: 0.6814
#
# Epoch 00005: val_loss did not improve from 0.62182
# Epoch 6/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6581 - accuracy: 0.6309 - val_loss: 0.6232 - val_accuracy: 0.6746
#
# Epoch 00006: val_loss did not improve from 0.62182
# Epoch 7/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6709 - accuracy: 0.6124 - val_loss: 0.6179 - val_accuracy: 0.6712
#
# Epoch 00007: val_loss improved from 0.62182 to 0.61786, saving model to ./model_titanic/07-0.6124.hdf5
# Epoch 8/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6479 - accuracy: 0.6493 - val_loss: 0.6071 - val_accuracy: 0.6881
#
# Epoch 00008: val_loss improved from 0.61786 to 0.60707, saving model to ./model_titanic/08-0.6493.hdf5
# Epoch 9/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6671 - accuracy: 0.6124 - val_loss: 0.7993 - val_accuracy: 0.4644
#
# Epoch 00009: val_loss did not improve from 0.60707
# Epoch 10/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6571 - accuracy: 0.6460 - val_loss: 0.6141 - val_accuracy: 0.6339
#
# Epoch 00010: val_loss did not improve from 0.60707
# Epoch 11/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6565 - accuracy: 0.6409 - val_loss: 0.6151 - val_accuracy: 0.6644
#
# Epoch 00011: val_loss did not improve from 0.60707
# Epoch 12/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6453 - accuracy: 0.6258 - val_loss: 0.6203 - val_accuracy: 0.6746
#
# Epoch 00012: val_loss did not improve from 0.60707
# Epoch 13/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6490 - accuracy: 0.6493 - val_loss: 0.5867 - val_accuracy: 0.6915
#
# Epoch 00013: val_loss improved from 0.60707 to 0.58672, saving model to ./model_titanic/13-0.6493.hdf5
# Epoch 14/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6430 - accuracy: 0.6628 - val_loss: 0.5870 - val_accuracy: 0.7119
#
# Epoch 00014: val_loss did not improve from 0.58672
# Epoch 15/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6469 - accuracy: 0.6678 - val_loss: 0.6142 - val_accuracy: 0.6780
#
# Epoch 00015: val_loss did not improve from 0.58672
# Epoch 16/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6450 - accuracy: 0.6527 - val_loss: 0.5762 - val_accuracy: 0.7017
#
# Epoch 00016: val_loss improved from 0.58672 to 0.57620, saving model to ./model_titanic/16-0.6527.hdf5
# Epoch 17/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6298 - accuracy: 0.6661 - val_loss: 0.6684 - val_accuracy: 0.6034
#
# Epoch 00017: val_loss did not improve from 0.57620
# Epoch 18/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6344 - accuracy: 0.6762 - val_loss: 0.5814 - val_accuracy: 0.7085
#
# Epoch 00018: val_loss did not improve from 0.57620
# Epoch 19/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6639 - accuracy: 0.6107 - val_loss: 0.6442 - val_accuracy: 0.6339
#
# Epoch 00019: val_loss did not improve from 0.57620
# Epoch 20/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6451 - accuracy: 0.6426 - val_loss: 0.6340 - val_accuracy: 0.7119
#
# Epoch 00020: val_loss did not improve from 0.57620
# Epoch 21/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6393 - accuracy: 0.6678 - val_loss: 0.6147 - val_accuracy: 0.6678
#
# Epoch 00021: val_loss did not improve from 0.57620
# Epoch 22/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6307 - accuracy: 0.6678 - val_loss: 0.6156 - val_accuracy: 0.7085
#
# Epoch 00022: val_loss did not improve from 0.57620
# Epoch 23/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6329 - accuracy: 0.6728 - val_loss: 0.5871 - val_accuracy: 0.6847
#
# Epoch 00023: val_loss did not improve from 0.57620
# Epoch 24/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6192 - accuracy: 0.6762 - val_loss: 0.5697 - val_accuracy: 0.7085
#
# Epoch 00024: val_loss improved from 0.57620 to 0.56971, saving model to ./model_titanic/24-0.6762.hdf5
# Epoch 25/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6306 - accuracy: 0.6812 - val_loss: 0.6003 - val_accuracy: 0.6847
#
# Epoch 00025: val_loss did not improve from 0.56971
# Epoch 26/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6229 - accuracy: 0.6930 - val_loss: 0.5965 - val_accuracy: 0.7153
#
# Epoch 00026: val_loss did not improve from 0.56971
# Epoch 27/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6126 - accuracy: 0.6896 - val_loss: 0.5614 - val_accuracy: 0.6983
#
# Epoch 00027: val_loss improved from 0.56971 to 0.56136, saving model to ./model_titanic/27-0.6896.hdf5
# Epoch 28/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6059 - accuracy: 0.6879 - val_loss: 0.6188 - val_accuracy: 0.7220
#
# Epoch 00028: val_loss did not improve from 0.56136
# Epoch 29/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6228 - accuracy: 0.6795 - val_loss: 0.6438 - val_accuracy: 0.6508
#
# Epoch 00029: val_loss did not improve from 0.56136
# Epoch 30/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6123 - accuracy: 0.6846 - val_loss: 0.7534 - val_accuracy: 0.5661
#
# Epoch 00030: val_loss did not improve from 0.56136
# Epoch 31/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6083 - accuracy: 0.6896 - val_loss: 0.6013 - val_accuracy: 0.6949
#
# Epoch 00031: val_loss did not improve from 0.56136
# Epoch 32/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6119 - accuracy: 0.6812 - val_loss: 0.5796 - val_accuracy: 0.7119
#
# Epoch 00032: val_loss did not improve from 0.56136
# Epoch 33/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6101 - accuracy: 0.6862 - val_loss: 0.5783 - val_accuracy: 0.7051
#
# Epoch 00033: val_loss did not improve from 0.56136
# Epoch 34/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6350 - accuracy: 0.6913 - val_loss: 0.6330 - val_accuracy: 0.7119
#
# Epoch 00034: val_loss did not improve from 0.56136
# Epoch 35/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6180 - accuracy: 0.6829 - val_loss: 0.5663 - val_accuracy: 0.7051
#
# Epoch 00035: val_loss did not improve from 0.56136
# Epoch 36/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6058 - accuracy: 0.6930 - val_loss: 0.7928 - val_accuracy: 0.5593
#
# Epoch 00036: val_loss did not improve from 0.56136
# Epoch 37/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5958 - accuracy: 0.7030 - val_loss: 0.6151 - val_accuracy: 0.6881
#
# Epoch 00037: val_loss did not improve from 0.56136
# Epoch 38/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6261 - accuracy: 0.6728 - val_loss: 0.5982 - val_accuracy: 0.6881
#
# Epoch 00038: val_loss did not improve from 0.56136
# Epoch 39/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6156 - accuracy: 0.6762 - val_loss: 0.6562 - val_accuracy: 0.6814
#
# Epoch 00039: val_loss did not improve from 0.56136
# Epoch 40/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5955 - accuracy: 0.6963 - val_loss: 0.5658 - val_accuracy: 0.7186
#
# Epoch 00040: val_loss did not improve from 0.56136
# Epoch 41/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5975 - accuracy: 0.6980 - val_loss: 0.5972 - val_accuracy: 0.7220
#
# Epoch 00041: val_loss did not improve from 0.56136
# Epoch 42/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5900 - accuracy: 0.6963 - val_loss: 0.6345 - val_accuracy: 0.7017
#
# Epoch 00042: val_loss did not improve from 0.56136
# Epoch 43/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5990 - accuracy: 0.7030 - val_loss: 0.6332 - val_accuracy: 0.7254
#
# Epoch 00043: val_loss did not improve from 0.56136
# Epoch 44/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5905 - accuracy: 0.6963 - val_loss: 0.7716 - val_accuracy: 0.5220
#
# Epoch 00044: val_loss did not improve from 0.56136
# Epoch 45/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5941 - accuracy: 0.7030 - val_loss: 0.5615 - val_accuracy: 0.7153
#
# Epoch 00045: val_loss did not improve from 0.56136
# Epoch 46/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5992 - accuracy: 0.6930 - val_loss: 0.5923 - val_accuracy: 0.7085
#
# Epoch 00046: val_loss did not improve from 0.56136
# Epoch 47/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5752 - accuracy: 0.7148 - val_loss: 0.7978 - val_accuracy: 0.5864
#
# Epoch 00047: val_loss did not improve from 0.56136
# Epoch 48/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5757 - accuracy: 0.7131 - val_loss: 0.6029 - val_accuracy: 0.7356
#
# Epoch 00048: val_loss did not improve from 0.56136
# Epoch 49/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5750 - accuracy: 0.7097 - val_loss: 0.7005 - val_accuracy: 0.7085
#
# Epoch 00049: val_loss did not improve from 0.56136
# Epoch 50/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5838 - accuracy: 0.7097 - val_loss: 0.6839 - val_accuracy: 0.6271
#
# Epoch 00050: val_loss did not improve from 0.56136
# Epoch 51/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6032 - accuracy: 0.7047 - val_loss: 0.6348 - val_accuracy: 0.7017
#
# Epoch 00051: val_loss did not improve from 0.56136
# Epoch 52/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5950 - accuracy: 0.6980 - val_loss: 0.6875 - val_accuracy: 0.6746
#
# Epoch 00052: val_loss did not improve from 0.56136
# Epoch 53/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5945 - accuracy: 0.7030 - val_loss: 0.5686 - val_accuracy: 0.7153
#
# Epoch 00053: val_loss did not improve from 0.56136
# Epoch 54/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.5938 - accuracy: 0.7047 - val_loss: 0.7027 - val_accuracy: 0.6102
#
# Epoch 00054: val_loss did not improve from 0.56136
# Epoch 55/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5808 - accuracy: 0.7164 - val_loss: 0.6074 - val_accuracy: 0.6983
#
# Epoch 00055: val_loss did not improve from 0.56136
# Epoch 56/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5793 - accuracy: 0.7064 - val_loss: 0.7833 - val_accuracy: 0.5559
#
# Epoch 00056: val_loss did not improve from 0.56136
# Epoch 57/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5931 - accuracy: 0.6930 - val_loss: 0.6330 - val_accuracy: 0.6780
#
# Epoch 00057: val_loss did not improve from 0.56136
# Epoch 58/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5715 - accuracy: 0.7198 - val_loss: 0.7113 - val_accuracy: 0.6847
#
# Epoch 00058: val_loss did not improve from 0.56136
# Epoch 59/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5694 - accuracy: 0.7097 - val_loss: 0.6302 - val_accuracy: 0.7051
#
# Epoch 00059: val_loss did not improve from 0.56136
# Epoch 60/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5828 - accuracy: 0.6980 - val_loss: 0.5996 - val_accuracy: 0.7254
#
# Epoch 00060: val_loss did not improve from 0.56136
# Epoch 61/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5630 - accuracy: 0.7198 - val_loss: 0.6782 - val_accuracy: 0.6441
#
# Epoch 00061: val_loss did not improve from 0.56136
# Epoch 62/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5995 - accuracy: 0.7013 - val_loss: 0.8482 - val_accuracy: 0.6441
#
# Epoch 00062: val_loss did not improve from 0.56136
# Epoch 63/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5794 - accuracy: 0.7215 - val_loss: 0.6059 - val_accuracy: 0.7288
#
# Epoch 00063: val_loss did not improve from 0.56136
# Epoch 64/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5834 - accuracy: 0.7215 - val_loss: 0.7287 - val_accuracy: 0.6102
#
# Epoch 00064: val_loss did not improve from 0.56136
# Epoch 65/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6129 - accuracy: 0.7064 - val_loss: 0.5986 - val_accuracy: 0.7153
#
# Epoch 00065: val_loss did not improve from 0.56136
# Epoch 66/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5651 - accuracy: 0.7232 - val_loss: 0.6163 - val_accuracy: 0.7186
#
# Epoch 00066: val_loss did not improve from 0.56136
# Epoch 67/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5595 - accuracy: 0.7198 - val_loss: 0.6135 - val_accuracy: 0.7220
#
# Epoch 00067: val_loss did not improve from 0.56136
# Epoch 68/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5577 - accuracy: 0.7181 - val_loss: 0.6406 - val_accuracy: 0.7390
#
# Epoch 00068: val_loss did not improve from 0.56136
# Epoch 69/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5637 - accuracy: 0.7114 - val_loss: 0.5817 - val_accuracy: 0.7220
#
# Epoch 00069: val_loss did not improve from 0.56136
# Epoch 70/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5622 - accuracy: 0.7181 - val_loss: 0.6068 - val_accuracy: 0.7186
#
# Epoch 00070: val_loss did not improve from 0.56136
# Epoch 71/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5646 - accuracy: 0.7097 - val_loss: 0.6000 - val_accuracy: 0.7220
#
# Epoch 00071: val_loss did not improve from 0.56136
# Epoch 72/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5518 - accuracy: 0.7265 - val_loss: 0.6400 - val_accuracy: 0.7186
#
# Epoch 00072: val_loss did not improve from 0.56136
# Epoch 73/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5529 - accuracy: 0.7181 - val_loss: 0.6035 - val_accuracy: 0.7254
#
# Epoch 00073: val_loss did not improve from 0.56136
# Epoch 74/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5679 - accuracy: 0.7181 - val_loss: 0.6696 - val_accuracy: 0.7085
#
# Epoch 00074: val_loss did not improve from 0.56136
# Epoch 75/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5550 - accuracy: 0.7198 - val_loss: 0.5954 - val_accuracy: 0.7186
#
# Epoch 00075: val_loss did not improve from 0.56136
# Epoch 76/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5693 - accuracy: 0.7198 - val_loss: 0.5839 - val_accuracy: 0.7254
#
# Epoch 00076: val_loss did not improve from 0.56136
# Epoch 77/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5666 - accuracy: 0.7232 - val_loss: 0.7670 - val_accuracy: 0.6305
#
# Epoch 00077: val_loss did not improve from 0.56136
# Epoch 78/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5574 - accuracy: 0.7181 - val_loss: 0.6149 - val_accuracy: 0.7254
#
# Epoch 00078: val_loss did not improve from 0.56136
# Epoch 79/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5534 - accuracy: 0.7198 - val_loss: 0.6036 - val_accuracy: 0.7153
#
# Epoch 00079: val_loss did not improve from 0.56136
# Epoch 80/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5538 - accuracy: 0.7114 - val_loss: 0.6362 - val_accuracy: 0.6881
#
# Epoch 00080: val_loss did not improve from 0.56136
# Epoch 81/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5403 - accuracy: 0.7349 - val_loss: 0.7244 - val_accuracy: 0.7119
#
# Epoch 00081: val_loss did not improve from 0.56136
# Epoch 82/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5432 - accuracy: 0.7047 - val_loss: 0.5930 - val_accuracy: 0.7153
#
# Epoch 00082: val_loss did not improve from 0.56136
# Epoch 83/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5719 - accuracy: 0.7148 - val_loss: 0.6397 - val_accuracy: 0.7085
#
# Epoch 00083: val_loss did not improve from 0.56136
# Epoch 84/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5510 - accuracy: 0.7198 - val_loss: 0.6731 - val_accuracy: 0.7390
#
# Epoch 00084: val_loss did not improve from 0.56136
# Epoch 85/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5477 - accuracy: 0.7148 - val_loss: 0.6425 - val_accuracy: 0.7153
#
# Epoch 00085: val_loss did not improve from 0.56136
# Epoch 86/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5431 - accuracy: 0.7299 - val_loss: 0.7602 - val_accuracy: 0.6000
#
# Epoch 00086: val_loss did not improve from 0.56136
# Epoch 87/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5363 - accuracy: 0.7282 - val_loss: 0.7016 - val_accuracy: 0.6305
#
# Epoch 00087: val_loss did not improve from 0.56136
# Epoch 88/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5635 - accuracy: 0.7081 - val_loss: 0.5910 - val_accuracy: 0.7186
#
# Epoch 00088: val_loss did not improve from 0.56136
# Epoch 89/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5548 - accuracy: 0.7265 - val_loss: 0.5702 - val_accuracy: 0.7153
#
# Epoch 00089: val_loss did not improve from 0.56136
# Epoch 90/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5754 - accuracy: 0.7265 - val_loss: 0.5716 - val_accuracy: 0.7254
#
# Epoch 00090: val_loss did not improve from 0.56136
# Epoch 91/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5680 - accuracy: 0.7215 - val_loss: 0.5699 - val_accuracy: 0.7254
#
# Epoch 00091: val_loss did not improve from 0.56136
# Epoch 92/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5549 - accuracy: 0.7232 - val_loss: 0.7256 - val_accuracy: 0.6610
#
# Epoch 00092: val_loss did not improve from 0.56136
# Epoch 93/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5606 - accuracy: 0.7198 - val_loss: 0.6565 - val_accuracy: 0.6712
#
# Epoch 00093: val_loss did not improve from 0.56136
# Epoch 94/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5566 - accuracy: 0.7315 - val_loss: 0.6168 - val_accuracy: 0.6847
#
# Epoch 00094: val_loss did not improve from 0.56136
# Epoch 95/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5454 - accuracy: 0.7315 - val_loss: 0.6025 - val_accuracy: 0.6949
#
# Epoch 00095: val_loss did not improve from 0.56136
# Epoch 96/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5457 - accuracy: 0.7416 - val_loss: 0.6424 - val_accuracy: 0.7017
#
# Epoch 00096: val_loss did not improve from 0.56136
# Epoch 97/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5302 - accuracy: 0.7399 - val_loss: 0.6157 - val_accuracy: 0.6949
#
# Epoch 00097: val_loss did not improve from 0.56136
# Epoch 98/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5248 - accuracy: 0.7668 - val_loss: 0.6653 - val_accuracy: 0.6949
#
# Epoch 00098: val_loss did not improve from 0.56136
# Epoch 99/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5472 - accuracy: 0.7416 - val_loss: 0.6093 - val_accuracy: 0.7051
#
# Epoch 00099: val_loss did not improve from 0.56136
# Epoch 100/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5244 - accuracy: 0.7483 - val_loss: 0.7655 - val_accuracy: 0.7153
#
# Epoch 00100: val_loss did not improve from 0.56136
# Epoch 101/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5169 - accuracy: 0.7416 - val_loss: 0.6314 - val_accuracy: 0.6678
#
# Epoch 00101: val_loss did not improve from 0.56136
# Epoch 102/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5441 - accuracy: 0.7131 - val_loss: 0.7302 - val_accuracy: 0.6339
#
# Epoch 00102: val_loss did not improve from 0.56136
# Epoch 103/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5085 - accuracy: 0.7517 - val_loss: 0.6515 - val_accuracy: 0.6915
#
# Epoch 00103: val_loss did not improve from 0.56136
# Epoch 104/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5093 - accuracy: 0.7483 - val_loss: 0.6206 - val_accuracy: 0.7119
#
# Epoch 00104: val_loss did not improve from 0.56136
# Epoch 105/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5022 - accuracy: 0.7534 - val_loss: 0.8239 - val_accuracy: 0.5356
#
# Epoch 00105: val_loss did not improve from 0.56136
# Epoch 106/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5161 - accuracy: 0.7466 - val_loss: 0.6188 - val_accuracy: 0.6814
#
# Epoch 00106: val_loss did not improve from 0.56136
# Epoch 107/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5487 - accuracy: 0.7232 - val_loss: 0.7251 - val_accuracy: 0.7220
#
# Epoch 00107: val_loss did not improve from 0.56136
# Epoch 108/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5064 - accuracy: 0.7701 - val_loss: 0.6929 - val_accuracy: 0.6610
#
# Epoch 00108: val_loss did not improve from 0.56136
# Epoch 109/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4906 - accuracy: 0.7584 - val_loss: 0.6910 - val_accuracy: 0.7288
#
# Epoch 00109: val_loss did not improve from 0.56136
# Epoch 110/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5295 - accuracy: 0.7617 - val_loss: 0.7171 - val_accuracy: 0.5763
#
# Epoch 00110: val_loss did not improve from 0.56136
# Epoch 111/2000
# 60/60 [==============================] - 1s 14ms/step - loss: 0.5371 - accuracy: 0.7466 - val_loss: 0.6029 - val_accuracy: 0.6746
#
# Epoch 00111: val_loss did not improve from 0.56136
# Epoch 112/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5291 - accuracy: 0.7433 - val_loss: 0.7172 - val_accuracy: 0.6305
#
# Epoch 00112: val_loss did not improve from 0.56136
# Epoch 113/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5251 - accuracy: 0.7433 - val_loss: 0.6119 - val_accuracy: 0.6475
#
# Epoch 00113: val_loss did not improve from 0.56136
# Epoch 114/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5101 - accuracy: 0.7550 - val_loss: 0.5876 - val_accuracy: 0.7220
#
# Epoch 00114: val_loss did not improve from 0.56136
# Epoch 115/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5067 - accuracy: 0.7601 - val_loss: 0.6799 - val_accuracy: 0.6373
#
# Epoch 00115: val_loss did not improve from 0.56136
# Epoch 116/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5156 - accuracy: 0.7601 - val_loss: 0.5458 - val_accuracy: 0.7119
#
# Epoch 00116: val_loss improved from 0.56136 to 0.54584, saving model to ./model_titanic/116-0.7601.hdf5
# Epoch 117/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4976 - accuracy: 0.7584 - val_loss: 0.5701 - val_accuracy: 0.6949
#
# Epoch 00117: val_loss did not improve from 0.54584
# Epoch 118/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4837 - accuracy: 0.7752 - val_loss: 0.5992 - val_accuracy: 0.7017
#
# Epoch 00118: val_loss did not improve from 0.54584
# Epoch 119/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5006 - accuracy: 0.7517 - val_loss: 0.6009 - val_accuracy: 0.7220
#
# Epoch 00119: val_loss did not improve from 0.54584
# Epoch 120/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4860 - accuracy: 0.7685 - val_loss: 0.7130 - val_accuracy: 0.5797
#
# Epoch 00120: val_loss did not improve from 0.54584
# Epoch 121/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4611 - accuracy: 0.7903 - val_loss: 0.6935 - val_accuracy: 0.6949
#
# Epoch 00121: val_loss did not improve from 0.54584
# Epoch 122/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4722 - accuracy: 0.7752 - val_loss: 0.5932 - val_accuracy: 0.6949
#
# Epoch 00122: val_loss did not improve from 0.54584
# Epoch 123/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4651 - accuracy: 0.7869 - val_loss: 0.6183 - val_accuracy: 0.7186
#
# Epoch 00123: val_loss did not improve from 0.54584
# Epoch 124/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5049 - accuracy: 0.7668 - val_loss: 0.5809 - val_accuracy: 0.7254
#
# Epoch 00124: val_loss did not improve from 0.54584
# Epoch 125/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4634 - accuracy: 0.7836 - val_loss: 0.7458 - val_accuracy: 0.6644
#
# Epoch 00125: val_loss did not improve from 0.54584
# Epoch 126/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4987 - accuracy: 0.7617 - val_loss: 0.7225 - val_accuracy: 0.6000
#
# Epoch 00126: val_loss did not improve from 0.54584
# Epoch 127/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5082 - accuracy: 0.7768 - val_loss: 0.6798 - val_accuracy: 0.6746
#
# Epoch 00127: val_loss did not improve from 0.54584
# Epoch 128/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5229 - accuracy: 0.7399 - val_loss: 0.6105 - val_accuracy: 0.7119
#
# Epoch 00128: val_loss did not improve from 0.54584
# Epoch 129/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4468 - accuracy: 0.7970 - val_loss: 0.7553 - val_accuracy: 0.6542
#
# Epoch 00129: val_loss did not improve from 0.54584
# Epoch 130/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4595 - accuracy: 0.8037 - val_loss: 0.6732 - val_accuracy: 0.7119
#
# Epoch 00130: val_loss did not improve from 0.54584
# Epoch 131/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4700 - accuracy: 0.7836 - val_loss: 0.7498 - val_accuracy: 0.6847
#
# Epoch 00131: val_loss did not improve from 0.54584
# Epoch 132/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4539 - accuracy: 0.7886 - val_loss: 0.7365 - val_accuracy: 0.7017
#
# Epoch 00132: val_loss did not improve from 0.54584
# Epoch 133/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4644 - accuracy: 0.7936 - val_loss: 0.6513 - val_accuracy: 0.6983
#
# Epoch 00133: val_loss did not improve from 0.54584
# Epoch 134/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4597 - accuracy: 0.7836 - val_loss: 0.6615 - val_accuracy: 0.6508
#
# Epoch 00134: val_loss did not improve from 0.54584
# Epoch 135/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4346 - accuracy: 0.7987 - val_loss: 0.8186 - val_accuracy: 0.6271
#
# Epoch 00135: val_loss did not improve from 0.54584
# Epoch 136/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.5098 - accuracy: 0.7752 - val_loss: 0.7474 - val_accuracy: 0.5797
#
# Epoch 00136: val_loss did not improve from 0.54584
# Epoch 137/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4804 - accuracy: 0.7785 - val_loss: 0.6087 - val_accuracy: 0.6847
#
# Epoch 00137: val_loss did not improve from 0.54584
# Epoch 138/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4549 - accuracy: 0.7936 - val_loss: 0.6611 - val_accuracy: 0.6847
#
# Epoch 00138: val_loss did not improve from 0.54584
# Epoch 139/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4497 - accuracy: 0.7852 - val_loss: 0.7617 - val_accuracy: 0.6339
#
# Epoch 00139: val_loss did not improve from 0.54584
# Epoch 140/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4622 - accuracy: 0.7886 - val_loss: 0.7286 - val_accuracy: 0.6237
#
# Epoch 00140: val_loss did not improve from 0.54584
# Epoch 141/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4474 - accuracy: 0.8037 - val_loss: 0.6711 - val_accuracy: 0.6881
#
# Epoch 00141: val_loss did not improve from 0.54584
# Epoch 142/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4336 - accuracy: 0.7987 - val_loss: 0.6328 - val_accuracy: 0.6983
#
# Epoch 00142: val_loss did not improve from 0.54584
# Epoch 143/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.4284 - accuracy: 0.8037 - val_loss: 0.7886 - val_accuracy: 0.6814
#
# Epoch 00143: val_loss did not improve from 0.54584
# Epoch 144/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4281 - accuracy: 0.8104 - val_loss: 0.6083 - val_accuracy: 0.6881
#
# Epoch 00144: val_loss did not improve from 0.54584
# Epoch 145/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4377 - accuracy: 0.7987 - val_loss: 0.6319 - val_accuracy: 0.7051
#
# Epoch 00145: val_loss did not improve from 0.54584
# Epoch 146/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4434 - accuracy: 0.7802 - val_loss: 0.6634 - val_accuracy: 0.6847
#
# Epoch 00146: val_loss did not improve from 0.54584
# Epoch 147/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4613 - accuracy: 0.7802 - val_loss: 0.6483 - val_accuracy: 0.6814
#
# Epoch 00147: val_loss did not improve from 0.54584
# Epoch 148/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4431 - accuracy: 0.8138 - val_loss: 0.6755 - val_accuracy: 0.6610
#
# Epoch 00148: val_loss did not improve from 0.54584
# Epoch 149/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4382 - accuracy: 0.8037 - val_loss: 0.6917 - val_accuracy: 0.6644
#
# Epoch 00149: val_loss did not improve from 0.54584
# Epoch 150/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4332 - accuracy: 0.7936 - val_loss: 0.7233 - val_accuracy: 0.6373
#
# Epoch 00150: val_loss did not improve from 0.54584
# Epoch 151/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4124 - accuracy: 0.8154 - val_loss: 0.7179 - val_accuracy: 0.6949
#
# Epoch 00151: val_loss did not improve from 0.54584
# Epoch 152/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4684 - accuracy: 0.7685 - val_loss: 0.6836 - val_accuracy: 0.7085
#
# Epoch 00152: val_loss did not improve from 0.54584
# Epoch 153/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4958 - accuracy: 0.7752 - val_loss: 0.6541 - val_accuracy: 0.6949
#
# Epoch 00153: val_loss did not improve from 0.54584
# Epoch 154/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4493 - accuracy: 0.7852 - val_loss: 0.6939 - val_accuracy: 0.7085
#
# Epoch 00154: val_loss did not improve from 0.54584
# Epoch 155/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4204 - accuracy: 0.8205 - val_loss: 0.8836 - val_accuracy: 0.6441
#
# Epoch 00155: val_loss did not improve from 0.54584
# Epoch 156/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4607 - accuracy: 0.7919 - val_loss: 0.8191 - val_accuracy: 0.6508
#
# Epoch 00156: val_loss did not improve from 0.54584
# Epoch 157/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4446 - accuracy: 0.8087 - val_loss: 0.8543 - val_accuracy: 0.6780
#
# Epoch 00157: val_loss did not improve from 0.54584
# Epoch 158/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4007 - accuracy: 0.8238 - val_loss: 0.7415 - val_accuracy: 0.7119
#
# Epoch 00158: val_loss did not improve from 0.54584
# Epoch 159/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4541 - accuracy: 0.8003 - val_loss: 0.7388 - val_accuracy: 0.6780
#
# Epoch 00159: val_loss did not improve from 0.54584
# Epoch 160/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4041 - accuracy: 0.8238 - val_loss: 0.7241 - val_accuracy: 0.6915
#
# Epoch 00160: val_loss did not improve from 0.54584
# Epoch 161/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4238 - accuracy: 0.7987 - val_loss: 1.0088 - val_accuracy: 0.4881
#
# Epoch 00161: val_loss did not improve from 0.54584
# Epoch 162/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4496 - accuracy: 0.7987 - val_loss: 0.7607 - val_accuracy: 0.6475
#
# Epoch 00162: val_loss did not improve from 0.54584
# Epoch 163/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3991 - accuracy: 0.8205 - val_loss: 0.7917 - val_accuracy: 0.6712
#
# Epoch 00163: val_loss did not improve from 0.54584
# Epoch 164/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4170 - accuracy: 0.8221 - val_loss: 0.7995 - val_accuracy: 0.6000
# Epoch 00164: val_loss did not improve from 0.54584
# Epoch 165/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4163 - accuracy: 0.8154 - val_loss: 0.6902 - val_accuracy: 0.7017
#
# Epoch 00165: val_loss did not improve from 0.54584
# Epoch 166/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4577 - accuracy: 0.7836 - val_loss: 0.7287 - val_accuracy: 0.7051
#
# Epoch 00166: val_loss did not improve from 0.54584
# Epoch 167/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4269 - accuracy: 0.8188 - val_loss: 0.6475 - val_accuracy: 0.6949
#
# Epoch 00167: val_loss did not improve from 0.54584
# Epoch 168/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4346 - accuracy: 0.7970 - val_loss: 0.7515 - val_accuracy: 0.6203
#
# Epoch 00168: val_loss did not improve from 0.54584
# Epoch 169/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4158 - accuracy: 0.8138 - val_loss: 0.6454 - val_accuracy: 0.6881
#
# Epoch 00169: val_loss did not improve from 0.54584
# Epoch 170/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4328 - accuracy: 0.8037 - val_loss: 0.7873 - val_accuracy: 0.6847
#
# Epoch 00170: val_loss did not improve from 0.54584
# Epoch 171/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3944 - accuracy: 0.8121 - val_loss: 0.6676 - val_accuracy: 0.7017
#
# Epoch 00171: val_loss did not improve from 0.54584
# Epoch 172/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4088 - accuracy: 0.8138 - val_loss: 0.6707 - val_accuracy: 0.6983
#
# Epoch 00172: val_loss did not improve from 0.54584
# Epoch 173/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3909 - accuracy: 0.8339 - val_loss: 0.6856 - val_accuracy: 0.6780
#
# Epoch 00173: val_loss did not improve from 0.54584
# Epoch 174/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3985 - accuracy: 0.8322 - val_loss: 0.7247 - val_accuracy: 0.6780
#
# Epoch 00174: val_loss did not improve from 0.54584
# Epoch 175/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4005 - accuracy: 0.8255 - val_loss: 0.6843 - val_accuracy: 0.6983
#
# Epoch 00175: val_loss did not improve from 0.54584
# Epoch 176/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3824 - accuracy: 0.8322 - val_loss: 0.7091 - val_accuracy: 0.7017
#
# Epoch 00176: val_loss did not improve from 0.54584
# Epoch 177/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3962 - accuracy: 0.8205 - val_loss: 0.7591 - val_accuracy: 0.7220
#
# Epoch 00177: val_loss did not improve from 0.54584
# Epoch 178/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4435 - accuracy: 0.8221 - val_loss: 0.6726 - val_accuracy: 0.6814
#
# Epoch 00178: val_loss did not improve from 0.54584
# Epoch 179/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3880 - accuracy: 0.8154 - val_loss: 0.9636 - val_accuracy: 0.6203
#
# Epoch 00179: val_loss did not improve from 0.54584
# Epoch 180/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4000 - accuracy: 0.8356 - val_loss: 0.8891 - val_accuracy: 0.5831
#
# Epoch 00180: val_loss did not improve from 0.54584
# Epoch 181/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3916 - accuracy: 0.8238 - val_loss: 0.8831 - val_accuracy: 0.6814
#
# Epoch 00181: val_loss did not improve from 0.54584
# Epoch 182/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4550 - accuracy: 0.7819 - val_loss: 0.7311 - val_accuracy: 0.6610
#
# Epoch 00182: val_loss did not improve from 0.54584
# Epoch 183/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4255 - accuracy: 0.8054 - val_loss: 0.7034 - val_accuracy: 0.6746
#
# Epoch 00183: val_loss did not improve from 0.54584
# Epoch 184/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3775 - accuracy: 0.8289 - val_loss: 0.7990 - val_accuracy: 0.6780
#
# Epoch 00184: val_loss did not improve from 0.54584
# Epoch 185/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3717 - accuracy: 0.8423 - val_loss: 0.7800 - val_accuracy: 0.6644
#
# Epoch 00185: val_loss did not improve from 0.54584
# Epoch 186/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4227 - accuracy: 0.8221 - val_loss: 0.6868 - val_accuracy: 0.6949
#
# Epoch 00186: val_loss did not improve from 0.54584
# Epoch 187/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.4016 - accuracy: 0.8255 - val_loss: 0.7638 - val_accuracy: 0.6644
#
# Epoch 00187: val_loss did not improve from 0.54584
# Epoch 188/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3918 - accuracy: 0.8138 - val_loss: 0.7837 - val_accuracy: 0.7017
#
# Epoch 00188: val_loss did not improve from 0.54584
# Epoch 189/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3781 - accuracy: 0.8339 - val_loss: 0.7816 - val_accuracy: 0.6678
#
# Epoch 00189: val_loss did not improve from 0.54584
# Epoch 190/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3654 - accuracy: 0.8339 - val_loss: 0.7241 - val_accuracy: 0.7153
#
# Epoch 00190: val_loss did not improve from 0.54584
# Epoch 191/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3965 - accuracy: 0.8087 - val_loss: 0.7736 - val_accuracy: 0.6407
#
# Epoch 00191: val_loss did not improve from 0.54584
# Epoch 192/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3813 - accuracy: 0.8356 - val_loss: 0.8280 - val_accuracy: 0.6169
#
# Epoch 00192: val_loss did not improve from 0.54584
# Epoch 193/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.4053 - accuracy: 0.8238 - val_loss: 0.9066 - val_accuracy: 0.5627
#
# Epoch 00193: val_loss did not improve from 0.54584
# Epoch 194/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3830 - accuracy: 0.8356 - val_loss: 0.7863 - val_accuracy: 0.6881
#
# Epoch 00194: val_loss did not improve from 0.54584
# Epoch 195/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3892 - accuracy: 0.8238 - val_loss: 0.8066 - val_accuracy: 0.6068
#
# Epoch 00195: val_loss did not improve from 0.54584
# Epoch 196/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3720 - accuracy: 0.8339 - val_loss: 0.8217 - val_accuracy: 0.6610
#
# Epoch 00196: val_loss did not improve from 0.54584
# Epoch 197/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3620 - accuracy: 0.8406 - val_loss: 0.9201 - val_accuracy: 0.6610
#
# Epoch 00197: val_loss did not improve from 0.54584
# Epoch 198/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3705 - accuracy: 0.8356 - val_loss: 0.7152 - val_accuracy: 0.7085
#
# Epoch 00198: val_loss did not improve from 0.54584
# Epoch 199/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4270 - accuracy: 0.8205 - val_loss: 0.6861 - val_accuracy: 0.6644
#
# Epoch 00199: val_loss did not improve from 0.54584
# Epoch 200/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4133 - accuracy: 0.8104 - val_loss: 0.7928 - val_accuracy: 0.6814
#
# Epoch 00200: val_loss did not improve from 0.54584
# Epoch 201/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3967 - accuracy: 0.8305 - val_loss: 0.7943 - val_accuracy: 0.6814
#
# Epoch 00201: val_loss did not improve from 0.54584
# Epoch 202/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3715 - accuracy: 0.8356 - val_loss: 0.7384 - val_accuracy: 0.6983
#
# Epoch 00202: val_loss did not improve from 0.54584
# Epoch 203/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3543 - accuracy: 0.8389 - val_loss: 1.0287 - val_accuracy: 0.6475
#
# Epoch 00203: val_loss did not improve from 0.54584
# Epoch 204/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3690 - accuracy: 0.8406 - val_loss: 1.0826 - val_accuracy: 0.5966
#
# Epoch 00204: val_loss did not improve from 0.54584
# Epoch 205/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.3585 - accuracy: 0.8423 - val_loss: 1.0923 - val_accuracy: 0.6610
#
# Epoch 00205: val_loss did not improve from 0.54584
# Epoch 206/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.4144 - accuracy: 0.7919 - val_loss: 0.7504 - val_accuracy: 0.6780
#
# Epoch 00206: val_loss did not improve from 0.54584
# Epoch 207/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3740 - accuracy: 0.8289 - val_loss: 0.7356 - val_accuracy: 0.6915
#
# Epoch 00207: val_loss did not improve from 0.54584
# Epoch 208/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3765 - accuracy: 0.8272 - val_loss: 0.7856 - val_accuracy: 0.6949
#
# Epoch 00208: val_loss did not improve from 0.54584
# Epoch 209/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3349 - accuracy: 0.8574 - val_loss: 0.9035 - val_accuracy: 0.6441
#
# Epoch 00209: val_loss did not improve from 0.54584
# Epoch 210/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3344 - accuracy: 0.8557 - val_loss: 1.1058 - val_accuracy: 0.6305
#
# Epoch 00210: val_loss did not improve from 0.54584
# Epoch 211/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3711 - accuracy: 0.8322 - val_loss: 1.0303 - val_accuracy: 0.6237
#
# Epoch 00211: val_loss did not improve from 0.54584
# Epoch 212/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3627 - accuracy: 0.8423 - val_loss: 0.9444 - val_accuracy: 0.6441
#
# Epoch 00212: val_loss did not improve from 0.54584
# Epoch 213/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3950 - accuracy: 0.8171 - val_loss: 0.8158 - val_accuracy: 0.6881
#
# Epoch 00213: val_loss did not improve from 0.54584
# Epoch 214/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4261 - accuracy: 0.8171 - val_loss: 0.7456 - val_accuracy: 0.6644
#
# Epoch 00214: val_loss did not improve from 0.54584
# Epoch 215/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3486 - accuracy: 0.8574 - val_loss: 0.9060 - val_accuracy: 0.6915
#
# Epoch 00215: val_loss did not improve from 0.54584
# Epoch 216/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3473 - accuracy: 0.8456 - val_loss: 0.9356 - val_accuracy: 0.6780
#
# Epoch 00216: val_loss did not improve from 0.54584
# Epoch 217/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3528 - accuracy: 0.8540 - val_loss: 0.8368 - val_accuracy: 0.7153
#
# Epoch 00217: val_loss did not improve from 0.54584
# Epoch 218/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3710 - accuracy: 0.8389 - val_loss: 0.8762 - val_accuracy: 0.6814
#
# Epoch 00218: val_loss did not improve from 0.54584
# Epoch 219/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3703 - accuracy: 0.8272 - val_loss: 0.8566 - val_accuracy: 0.6847
#
# Epoch 00219: val_loss did not improve from 0.54584
# Epoch 220/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3558 - accuracy: 0.8389 - val_loss: 0.9785 - val_accuracy: 0.6475
#
# Epoch 00220: val_loss did not improve from 0.54584
# Epoch 221/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3651 - accuracy: 0.8322 - val_loss: 0.8870 - val_accuracy: 0.6746
#
# Epoch 00221: val_loss did not improve from 0.54584
# Epoch 222/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3435 - accuracy: 0.8540 - val_loss: 0.9728 - val_accuracy: 0.6576
#
# Epoch 00222: val_loss did not improve from 0.54584
# Epoch 223/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3984 - accuracy: 0.8339 - val_loss: 1.4815 - val_accuracy: 0.5288
#
# Epoch 00223: val_loss did not improve from 0.54584
# Epoch 224/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4493 - accuracy: 0.8070 - val_loss: 0.9562 - val_accuracy: 0.6814
#
# Epoch 00224: val_loss did not improve from 0.54584
# Epoch 225/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4005 - accuracy: 0.8305 - val_loss: 0.8064 - val_accuracy: 0.6475
#
# Epoch 00225: val_loss did not improve from 0.54584
# Epoch 226/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3664 - accuracy: 0.8339 - val_loss: 0.7757 - val_accuracy: 0.6814
#
# Epoch 00226: val_loss did not improve from 0.54584
# Epoch 227/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3705 - accuracy: 0.8339 - val_loss: 0.9190 - val_accuracy: 0.6780
#
# Epoch 00227: val_loss did not improve from 0.54584
# Epoch 228/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3391 - accuracy: 0.8658 - val_loss: 1.2780 - val_accuracy: 0.6610
#
# Epoch 00228: val_loss did not improve from 0.54584
# Epoch 229/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3627 - accuracy: 0.8372 - val_loss: 0.8810 - val_accuracy: 0.6983
#
# Epoch 00229: val_loss did not improve from 0.54584
# Epoch 230/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3348 - accuracy: 0.8557 - val_loss: 0.8333 - val_accuracy: 0.7186
#
# Epoch 00230: val_loss did not improve from 0.54584
# Epoch 231/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4481 - accuracy: 0.7936 - val_loss: 0.8098 - val_accuracy: 0.6746
#
# Epoch 00231: val_loss did not improve from 0.54584
# Epoch 232/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3809 - accuracy: 0.8507 - val_loss: 0.7061 - val_accuracy: 0.7322
#
# Epoch 00232: val_loss did not improve from 0.54584
# Epoch 233/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3657 - accuracy: 0.8473 - val_loss: 0.7677 - val_accuracy: 0.6780
#
# Epoch 00233: val_loss did not improve from 0.54584
# Epoch 234/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3322 - accuracy: 0.8674 - val_loss: 1.0903 - val_accuracy: 0.6576
#
# Epoch 00234: val_loss did not improve from 0.54584
# Epoch 235/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3517 - accuracy: 0.8406 - val_loss: 0.8446 - val_accuracy: 0.7186
#
# Epoch 00235: val_loss did not improve from 0.54584
# Epoch 236/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3395 - accuracy: 0.8473 - val_loss: 1.0171 - val_accuracy: 0.6678
#
# Epoch 00236: val_loss did not improve from 0.54584
# Epoch 237/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3606 - accuracy: 0.8456 - val_loss: 0.8697 - val_accuracy: 0.7119
#
# Epoch 00237: val_loss did not improve from 0.54584
# Epoch 238/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3602 - accuracy: 0.8523 - val_loss: 1.4147 - val_accuracy: 0.5966
#
# Epoch 00238: val_loss did not improve from 0.54584
# Epoch 239/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.4191 - accuracy: 0.8138 - val_loss: 0.8304 - val_accuracy: 0.7322
#
# Epoch 00239: val_loss did not improve from 0.54584
# Epoch 240/2000
# 60/60 [==============================] - 1s 14ms/step - loss: 0.3959 - accuracy: 0.8205 - val_loss: 0.7113 - val_accuracy: 0.7017
#
# Epoch 00240: val_loss did not improve from 0.54584
# Epoch 241/2000
# ...
#
# Epoch 00707: val_loss did not improve from 0.54584
# Epoch 708/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1271 - accuracy: 0.9497 - val_loss: 3.2687 - val_accuracy: 0.5898
#
# Epoch 00708: val_loss did not improve from 0.54584
# Epoch 709/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2080 - accuracy: 0.9279 - val_loss: 2.9062 - val_accuracy: 0.6407
#
# Epoch 00709: val_loss did not improve from 0.54584
# Epoch 710/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1705 - accuracy: 0.9413 - val_loss: 2.7060 - val_accuracy: 0.6576
#
# Epoch 00710: val_loss did not improve from 0.54584
# Epoch 711/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1726 - accuracy: 0.9211 - val_loss: 3.8951 - val_accuracy: 0.6305
#
# Epoch 00711: val_loss did not improve from 0.54584
# Epoch 712/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1961 - accuracy: 0.9346 - val_loss: 3.7167 - val_accuracy: 0.6102
#
# Epoch 00712: val_loss did not improve from 0.54584
# Epoch 713/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1988 - accuracy: 0.9178 - val_loss: 3.8952 - val_accuracy: 0.5898
#
# Epoch 00713: val_loss did not improve from 0.54584
# Epoch 714/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1902 - accuracy: 0.9295 - val_loss: 2.4793 - val_accuracy: 0.6847
#
# Epoch 00714: val_loss did not improve from 0.54584
# Epoch 715/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1693 - accuracy: 0.9430 - val_loss: 2.9687 - val_accuracy: 0.5831
#
# Epoch 00715: val_loss did not improve from 0.54584
# Epoch 716/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1735 - accuracy: 0.9312 - val_loss: 2.4810 - val_accuracy: 0.6271
#
# Epoch 00716: val_loss did not improve from 0.54584
# Epoch 717/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1523 - accuracy: 0.9413 - val_loss: 2.3233 - val_accuracy: 0.5898
#
# Epoch 00717: val_loss did not improve from 0.54584
# Epoch 718/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1721 - accuracy: 0.9178 - val_loss: 2.1014 - val_accuracy: 0.6407
#
# Epoch 00718: val_loss did not improve from 0.54584
# Epoch 719/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1679 - accuracy: 0.9346 - val_loss: 3.3179 - val_accuracy: 0.6034
#
# Epoch 00719: val_loss did not improve from 0.54584
# Epoch 720/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1592 - accuracy: 0.9362 - val_loss: 3.4840 - val_accuracy: 0.5932
#
# Epoch 00720: val_loss did not improve from 0.54584
# Epoch 721/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2064 - accuracy: 0.9211 - val_loss: 3.4989 - val_accuracy: 0.5593
#
# Epoch 00721: val_loss did not improve from 0.54584
# Epoch 722/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1421 - accuracy: 0.9463 - val_loss: 3.5402 - val_accuracy: 0.5864
#
# Epoch 00722: val_loss did not improve from 0.54584
# Epoch 723/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1530 - accuracy: 0.9446 - val_loss: 3.6395 - val_accuracy: 0.6339
#
# Epoch 00723: val_loss did not improve from 0.54584
# Epoch 724/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1421 - accuracy: 0.9446 - val_loss: 3.1811 - val_accuracy: 0.6000
#
# Epoch 00724: val_loss did not improve from 0.54584
# Epoch 725/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1223 - accuracy: 0.9513 - val_loss: 3.2844 - val_accuracy: 0.6237
#
# Epoch 00725: val_loss did not improve from 0.54584
# Epoch 726/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1073 - accuracy: 0.9513 - val_loss: 4.4368 - val_accuracy: 0.6000
#
# Epoch 00726: val_loss did not improve from 0.54584
# Epoch 727/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0931 - accuracy: 0.9681 - val_loss: 3.3814 - val_accuracy: 0.6305
#
# Epoch 00727: val_loss did not improve from 0.54584
# Epoch 728/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1945 - accuracy: 0.9362 - val_loss: 2.9131 - val_accuracy: 0.5627
#
# Epoch 00728: val_loss did not improve from 0.54584
# Epoch 729/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2768 - accuracy: 0.8977 - val_loss: 2.9206 - val_accuracy: 0.5932
#
# Epoch 00729: val_loss did not improve from 0.54584
# Epoch 730/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2740 - accuracy: 0.8859 - val_loss: 1.8436 - val_accuracy: 0.5627
#
# Epoch 00730: val_loss did not improve from 0.54584
# Epoch 731/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2152 - accuracy: 0.9228 - val_loss: 1.3940 - val_accuracy: 0.6203
#
# Epoch 00731: val_loss did not improve from 0.54584
# Epoch 732/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2675 - accuracy: 0.9161 - val_loss: 2.4315 - val_accuracy: 0.4983
#
# Epoch 00732: val_loss did not improve from 0.54584
# Epoch 733/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3092 - accuracy: 0.8708 - val_loss: 1.3972 - val_accuracy: 0.5390
#
# Epoch 00733: val_loss did not improve from 0.54584
# Epoch 734/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.2759 - accuracy: 0.9262 - val_loss: 1.2057 - val_accuracy: 0.6136
#
# Epoch 00734: val_loss did not improve from 0.54584
# Epoch 735/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1647 - accuracy: 0.9346 - val_loss: 1.6060 - val_accuracy: 0.6034
#
# Epoch 00735: val_loss did not improve from 0.54584
# Epoch 736/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1494 - accuracy: 0.9362 - val_loss: 1.6107 - val_accuracy: 0.6576
#
# Epoch 00736: val_loss did not improve from 0.54584
# Epoch 737/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1632 - accuracy: 0.9362 - val_loss: 2.1911 - val_accuracy: 0.5797
#
# Epoch 00737: val_loss did not improve from 0.54584
# Epoch 738/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1381 - accuracy: 0.9463 - val_loss: 2.4211 - val_accuracy: 0.6237
#
# Epoch 00738: val_loss did not improve from 0.54584
# Epoch 739/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1619 - accuracy: 0.9346 - val_loss: 1.6251 - val_accuracy: 0.6305
#
# Epoch 00739: val_loss did not improve from 0.54584
# Epoch 740/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2349 - accuracy: 0.9077 - val_loss: 1.5127 - val_accuracy: 0.6644
#
# Epoch 00740: val_loss did not improve from 0.54584
# Epoch 741/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2110 - accuracy: 0.9144 - val_loss: 1.7764 - val_accuracy: 0.5966
#
# Epoch 00741: val_loss did not improve from 0.54584
# Epoch 742/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1192 - accuracy: 0.9430 - val_loss: 2.4137 - val_accuracy: 0.5797
#
# Epoch 00742: val_loss did not improve from 0.54584
# Epoch 743/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1247 - accuracy: 0.9480 - val_loss: 2.3590 - val_accuracy: 0.6339
#
# Epoch 00743: val_loss did not improve from 0.54584
# Epoch 744/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1366 - accuracy: 0.9463 - val_loss: 2.6770 - val_accuracy: 0.5966
#
# Epoch 00744: val_loss did not improve from 0.54584
# Epoch 745/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2154 - accuracy: 0.9228 - val_loss: 2.2814 - val_accuracy: 0.5966
# Epoch 00745: val_loss did not improve from 0.54584
# Epoch 746/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1679 - accuracy: 0.9329 - val_loss: 2.6261 - val_accuracy: 0.6644
#
# Epoch 00746: val_loss did not improve from 0.54584
# Epoch 747/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1442 - accuracy: 0.9463 - val_loss: 2.2303 - val_accuracy: 0.6644
#
# Epoch 00747: val_loss did not improve from 0.54584
# Epoch 748/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2484 - accuracy: 0.9060 - val_loss: 1.6655 - val_accuracy: 0.6237
#
# Epoch 00748: val_loss did not improve from 0.54584
# Epoch 749/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1894 - accuracy: 0.9161 - val_loss: 1.6715 - val_accuracy: 0.6237
#
# Epoch 00749: val_loss did not improve from 0.54584
# Epoch 750/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1273 - accuracy: 0.9480 - val_loss: 3.2553 - val_accuracy: 0.6000
#
# Epoch 00750: val_loss did not improve from 0.54584
# Epoch 751/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1144 - accuracy: 0.9530 - val_loss: 2.6253 - val_accuracy: 0.5627
#
# Epoch 00751: val_loss did not improve from 0.54584
# Epoch 752/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2034 - accuracy: 0.9161 - val_loss: 2.0378 - val_accuracy: 0.6305
#
# Epoch 00752: val_loss did not improve from 0.54584
# Epoch 753/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1317 - accuracy: 0.9480 - val_loss: 2.3984 - val_accuracy: 0.6203
#
# Epoch 00753: val_loss did not improve from 0.54584
# Epoch 754/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1568 - accuracy: 0.9346 - val_loss: 2.2383 - val_accuracy: 0.6271
#
# Epoch 00754: val_loss did not improve from 0.54584
# Epoch 755/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1327 - accuracy: 0.9396 - val_loss: 2.5053 - val_accuracy: 0.6373
#
# Epoch 00755: val_loss did not improve from 0.54584
# Epoch 756/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1027 - accuracy: 0.9597 - val_loss: 3.3574 - val_accuracy: 0.6576
#
# Epoch 00756: val_loss did not improve from 0.54584
# Epoch 757/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0917 - accuracy: 0.9681 - val_loss: 3.7469 - val_accuracy: 0.6102
#
# Epoch 00757: val_loss did not improve from 0.54584
# Epoch 758/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1403 - accuracy: 0.9480 - val_loss: 3.6967 - val_accuracy: 0.5864
#
# Epoch 00758: val_loss did not improve from 0.54584
# Epoch 759/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1611 - accuracy: 0.9396 - val_loss: 1.9458 - val_accuracy: 0.6203
#
# Epoch 00759: val_loss did not improve from 0.54584
# Epoch 760/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1307 - accuracy: 0.9581 - val_loss: 1.6796 - val_accuracy: 0.6034
#
# Epoch 00760: val_loss did not improve from 0.54584
# Epoch 761/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1324 - accuracy: 0.9413 - val_loss: 2.3545 - val_accuracy: 0.6339
#
# Epoch 00761: val_loss did not improve from 0.54584
# Epoch 762/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1349 - accuracy: 0.9379 - val_loss: 2.0940 - val_accuracy: 0.6339
#
# Epoch 00762: val_loss did not improve from 0.54584
# Epoch 763/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0949 - accuracy: 0.9564 - val_loss: 2.6259 - val_accuracy: 0.6102
#
# Epoch 00763: val_loss did not improve from 0.54584
# Epoch 764/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1140 - accuracy: 0.9564 - val_loss: 2.1238 - val_accuracy: 0.6576
#
# Epoch 00764: val_loss did not improve from 0.54584
# Epoch 765/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2204 - accuracy: 0.9279 - val_loss: 1.4552 - val_accuracy: 0.6780
#
# Epoch 00765: val_loss did not improve from 0.54584
# Epoch 766/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3354 - accuracy: 0.8641 - val_loss: 1.4962 - val_accuracy: 0.6339
#
# Epoch 00766: val_loss did not improve from 0.54584
# Epoch 767/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2008 - accuracy: 0.9178 - val_loss: 3.9783 - val_accuracy: 0.5831
#
# Epoch 00767: val_loss did not improve from 0.54584
# Epoch 768/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.1823 - accuracy: 0.9295 - val_loss: 1.4642 - val_accuracy: 0.6169
#
# Epoch 00768: val_loss did not improve from 0.54584
# Epoch 769/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1244 - accuracy: 0.9480 - val_loss: 1.2641 - val_accuracy: 0.6542
#
# Epoch 00769: val_loss did not improve from 0.54584
# Epoch 770/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.1268 - accuracy: 0.9463 - val_loss: 1.3590 - val_accuracy: 0.6610
#
# Epoch 00770: val_loss did not improve from 0.54584
# Epoch 771/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1227 - accuracy: 0.9446 - val_loss: 1.7820 - val_accuracy: 0.5932
#
# Epoch 00771: val_loss did not improve from 0.54584
# Epoch 772/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0976 - accuracy: 0.9581 - val_loss: 1.6906 - val_accuracy: 0.6203
#
# Epoch 00772: val_loss did not improve from 0.54584
# Epoch 773/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.1538 - accuracy: 0.9480 - val_loss: 1.5328 - val_accuracy: 0.6339
#
# Epoch 00773: val_loss did not improve from 0.54584
# Epoch 774/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.1563 - accuracy: 0.9446 - val_loss: 2.1982 - val_accuracy: 0.6203
#
# Epoch 00774: val_loss did not improve from 0.54584
# Epoch 775/2000
# 60/60 [==============================] - 1s 13ms/step - loss: 0.1108 - accuracy: 0.9547 - val_loss: 1.8702 - val_accuracy: 0.6102
#
# Epoch 00775: val_loss did not improve from 0.54584
# Epoch 776/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1252 - accuracy: 0.9446 - val_loss: 1.7268 - val_accuracy: 0.6644
#
# Epoch 00776: val_loss did not improve from 0.54584
# Epoch 777/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1250 - accuracy: 0.9463 - val_loss: 2.5722 - val_accuracy: 0.6169
#
# Epoch 00777: val_loss did not improve from 0.54584
# Epoch 778/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1749 - accuracy: 0.9362 - val_loss: 2.4744 - val_accuracy: 0.5763
#
# Epoch 00778: val_loss did not improve from 0.54584
# Epoch 779/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1004 - accuracy: 0.9564 - val_loss: 1.9860 - val_accuracy: 0.6271
#
# Epoch 00779: val_loss did not improve from 0.54584
# Epoch 780/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1323 - accuracy: 0.9463 - val_loss: 1.9243 - val_accuracy: 0.6339
#
# Epoch 00780: val_loss did not improve from 0.54584
# Epoch 781/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2548 - accuracy: 0.9161 - val_loss: 2.6143 - val_accuracy: 0.5831
#
# Epoch 00781: val_loss did not improve from 0.54584
# Epoch 782/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1773 - accuracy: 0.9228 - val_loss: 1.8891 - val_accuracy: 0.6169
#
# Epoch 00782: val_loss did not improve from 0.54584
# Epoch 783/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1674 - accuracy: 0.9379 - val_loss: 2.9011 - val_accuracy: 0.6237
#
# Epoch 00783: val_loss did not improve from 0.54584
# Epoch 784/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2548 - accuracy: 0.8943 - val_loss: 1.6601 - val_accuracy: 0.6373
#
# Epoch 00784: val_loss did not improve from 0.54584
# Epoch 785/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2534 - accuracy: 0.8993 - val_loss: 1.3800 - val_accuracy: 0.6542
#
# Epoch 00785: val_loss did not improve from 0.54584
# Epoch 786/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.2029 - accuracy: 0.9178 - val_loss: 1.3186 - val_accuracy: 0.6068
#
# Epoch 00786: val_loss did not improve from 0.54584
# Epoch 787/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.1176 - accuracy: 0.9564 - val_loss: 1.5771 - val_accuracy: 0.6034
#
# Epoch 00787: val_loss did not improve from 0.54584
# Epoch 788/2000
# 43/60 [====================>.........] - ETA: 0s - loss: 0.1027 - accuracy: 0.9581

# %%
data = [[1,2,3,4],[5,6,7,8]]

dataframe = pd.DateFrame(data)
dataframe.to_csv("/Users/panhong/coding_study/Likelion_KDT/Jupyter_notebook/csv_file" , header = False , index = False)
