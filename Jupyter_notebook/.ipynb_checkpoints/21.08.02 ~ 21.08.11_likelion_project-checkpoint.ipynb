# %%
import cv2
import numpy as np

# %%
# 마우스를 이용해서 관심영역 설정 후 이미지 저장
isDragging = False
x0 , y0 , w , h = -1 , -1 , -1 , -1
blue , red = (255 , 0 , 0) , (0 , 0 , 255)

def onMouse(event , x , y , flags , param):
    global isDragging , x0 , y0 , img 
    # 마우스 왼쪽버튼 클릭시
    if event == cv2.EVENT_LBUTTONDOWN:
        isDragging = True
        x0 = x
        y0 = y
    # 왼쪽 버튼을 누를채로 마우스 움직일시
    elif event == cv2.EVENT_MOUSEMOVE:
        if isDragging:
            # 이미지를 카피
            img_draw = img.copy()
            # x = x축 , y = y축 , w = width , h = height
            # rentangle = 도형그리기 함수(매개변수들은 도형을 그릴 이미지 , 도형의 x , y , w , h값 , 색상이다.)
            cv2.rectangle(img_draw , (x0 , y0) , (x , y) , blue , 2)
            
            # 슬라이싱당한 image의 원본을 출력
            cv2.imshow("img" , img_draw)
            
    # 마우스 왼쪽 버튼에서 손을 땠을떄
    elif event == cv2.EVENT_LBUTTONUP:
        # 드래깅을 False로 변경 , 그리기 금지
        if isDragging:
            isDragging = False
            w = x - x0
            h = y - y0
            # 드래깅이 완료되면 베이스 이미지에서 드래깅된 구역의 x , y , w , h 값을 출력해줌
            print("x : %d , y : %d , w : %d , h : %d" %(x0 , y0 , w , h))
            # 드래깅이 제대로 되었다면 당연히  w , h는 0보다 클수밖에 없다.
            if w > 0 and h > 0:
                # 이미지를 카피
                img_draw = img.copy()
                # 이미지에 슬라이싱할 부위에 사각형 그려주기
                cv2.rectangle(img_draw , (x0 , y0) , (x , y) , red , 2)
                # 기본 베이스 이미지 출력
                cv2.imshow("img" , img_draw)
                # roi = 원하는 이미지의 부분(사용자가 직접 슬라이싱한 부분)
                roi = img[y0 : y0 + h , x0 : x0 + w]
                # 슬라이싱한 이미지를 출력
                cv2.imshow("cropped" , roi)
                # 슬라이싱한 이미지가 출력될 윈도우의 위치를 설정 
                cv2.moveWindow("cropped" , 0 , 0)
                # 이미지 저장
                cv2.imwrite("/Users/panhong/Desktop/baseball/cropped.jpg" , roi)
                print("cropped")
            else:
                # 똑바로 드래깅을 못했을시
                cv2.imshow("img" , img)
                print("좌측 상단에서 우측 하단으로 영역을 드래그 하세요.")
                
# 읽을 이미지 불러오기
img = cv2.imread("/Users/panhong/Desktop/baseball/오타니.png")
# 불러온 이미지 출력
cv2.imshow("img" , img)

# onMouse에 매개변수는 x , y , flags , parms가 필요한데 
# setMousecallback 함수에는 해당 내용들이 입력이 되므로 onMouse함수를 이용할 수가 있음
cv2.setMouseCallback("img" , onMouse)

# 사용자가 슬라이싱한 이미지를 출력
img_2 = cv2.imread("/Users/panhong/Desktop/baseball/cropped.jpg")
cv2.imshow("tracking" , img_2)

# 생선된 윈도우 전부제거
cv2.waitKey()
cv2.destroyAllWindows()
cv2.waitKey(1)
cv2.waitKey(1)
cv2.waitKey(1)
# Out:
# x : 513 , y : 238 , w : 665 , h : 721
# cropped
# -1

# %%
# 슬라이싱한 부분을 motion tracking한 모습으로 출력
from openpose import motion_tracking
import cv2

# 기존에 작성해놓은 motion tracking class를 이용해서 상단에 cropped된 이미지를 읽어서
# 관절부위에 점을 찍고 라인을 그어줌
tracking = motion_tracking()
img = cv2.imread("/Users/panhong/Desktop/baseball/cropped.jpg")
tracking.tracking_motion(img)
# Out:
# 이미지 ID :  44 , H :  89 , W :  80
# 0  와  1  연결
#
# 1  와  2  연결
#
# 2  와  3  연결
#
# 3  와  4  연결
#
# 1  와  5  연결
#
# 5  와  6  연결
#
# 6  와  7  연결
#
# 1  와  14  연결
#
# 14  와  8  연결
#
# 8  와  9  연결
#
# 9  와  10  연결
#
# 14  와  11  연결
#
# 11  와  12  연결
#
# 12  와  13  연결

# %%
# 상단 마우스로 처리한 부분을 마우스로 하지않고 코딩을 이용해서 원하는 부위를 설정
img = cv2.imread("/Users/panhong/Desktop/baseball/오타니.png")

# x , y , w , h == 이미지내에서 슬라이싱을 원하는부위의 좌표값
x = 592 
y = 248
w = 522
h = 692

# roi == 원하는 위치
roi = img[y : y + h , x : x + w]

# roi에 해당하는 좌표의 위치와 컬러인지 흑백인지 출력해줌
print(roi.shape)

# 설정한 위치에 사각형 도형을 그려줌
cv2.rectangle(roi , (0 , 0) , (h - 1 , w - 1) , (0 , 0 , 255))

# 이미지 출력
cv2.imshow("img" , img)
cv2.waitKey()
cv2.destroyAllWindows()
cv2.waitKey(1)
cv2.waitKey(1)
cv2.waitKey(1)
# Out:
# (692, 522, 3)
# -1

# %%
# 해당되는 영상을 흑백처리
import cv2  
import numpy as np
import argparse
import matplotlib.pyplot as plt

# 비디오 불러오기
cap = cv2.VideoCapture("/Users/panhong/Desktop/baseball/오타니.mov")
# 프레임 레이트(영상진행속도) 가져오기 
# 1초동안 가져올 프레임의 개수를 설정
# 가져오는 프레임의 숫자가 작을수록 슬로우모션으로 영상이 진행
fps = cap.get(cv2.CAP_PROP_FPS)

# 해당연산은 영상의 프레임사이의 간격을 볼 수 확인할수 있다.
# 예를 들어 해당식을 연산해서 delay를 print해보았을때 출력값이 30이라면 
# 해당 영상의 1초당 출력하는 프레임은 30개라는 뜻이됩니다. 
delay = int(1000/fps)

# 영상의 배경을 지워주는 함수 (움직이는 객체는 흰색으로 표시되며 배경만 있는
# 영상이나 이미지일 경우는 검은색 화면만 출력됨)
# 주로 cctv에서 객체의 움직임을 확인할때 사용함

# SubtractorMOG2 , SubtractorGMG 함수종류가 있음 
# 대부분 비슷하지만 약간의 차이점은 존재함
fgbg = cv2.bgsegm.createBackgroundSubtractorMOG()

# isOpened함수는 해당 영상이 제대로 열렸는지 확인을 할 수 있는함수
# isOpened함수와 조건문을 이용해서 더 정확하게 영상이
# 제대로 열렸는지 확인이 가능함
while cap.isOpened():
    from video_tracking import video_tracking
    tracking = video_tracking()
    # 영상이 제대로 열렸다면 ret의 값은 True가 됩니다.
    # frame = 영상의 프레임을 가져옵니다.
    ret , frame = cap.read()
    # ret = False라면 해당 반복문을 중단시킵니다.
    if not ret:
        break
    # apply함수도 마찬가지로 영상의 정적인 부분을 흑색으로 변화시키고
    # 동적인 부분은 흰색으로 남기는 함수임
    fgmask = fgbg.apply(frame)
    # 변색되지 않은 온전한 영상 출력
    cv2.imshow("frame" , frame)
    # 동적인 부분만 흰색으로 출력되게 설정해준 영상을 출력
    cv2.imshow("bgsub" , fgmask)
    tracking.tracking_video(cap)
    # waitKey함수를 이용해서 키보드 이벤트 감지
    # 아무버튼이나 이벤트가 발생하면 반복문 중단
    if cv2.waitKey(1) & 0xff == 27:
        break
        
# release함수를 이용해서 불러온 영상의파일 , 캡처 장치를 닫아줌 
# 닫아주지 않을지 백그라운드에서 계속 작동중이므로 
# 작업에 방해를 주는 요인으로 작용됨
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
cv2.waitKey(1)
cv2.waitKey(1)
# Out:
# -1

# %%
# # 이미지 스켈레톤 그리기
# import cv2

# # 이미지 , 영상을 분석해서 적절한 위치의 관절 포인트의 번호를 
# # 지정해준 딕셔너리 전신부터 배경까지 총 15번까지의 포인트 번호
# BODY_PARTS = { "Head": 0, "Neck": 1, "RShoulder": 2, "RElbow": 3, "RWrist": 4,
#                 "LShoulder": 5, "LElbow": 6, "LWrist": 7, "RHip": 8, "RKnee": 9,
#                 "RAnkle": 10, "LHip": 11, "LKnee": 12, "LAnkle": 13, "Chest": 14,
#                 "Background": 15 }

# # 최종출력시 관절들의 위치를 점으로 찍고 점을 연결시켜주어야 하므로 
# # 라인이 중구난방하게 그어지지 않게 관절의 연결도를 각각 리스트로 묶어놓았음 
# # [머리 , 목 ] , [목 , 좌측어깨] , [목 , 우측어깨]
# POSE_PAIRS = [ ["Head", "Neck"], ["Neck", "RShoulder"], ["RShoulder", "RElbow"],
#                 ["RElbow", "RWrist"], ["Neck", "LShoulder"], ["LShoulder", "LElbow"],
#                 ["LElbow", "LWrist"], ["Neck", "Chest"], ["Chest", "RHip"], ["RHip", "RKnee"],
#                 ["RKnee", "RAnkle"], ["Chest", "LHip"], ["LHip", "LKnee"], ["LKnee", "LAnkle"] ]
    
# # prototext = 네트워크 구조가 담긴 파일
# # caffe model은 prototext 파일로 학습이 되고 학습된 모델의 이름이 
# # caffemodel이 된다. 
# # caffe에서 사용할 protobuf들의 정의는 caffe.proto에서 확인가능
# protoFile = "/Users/panhong/Desktop/openpose_sample/pose_deploy_linevec_faster_4_stages.prototxt"

# # caffemodel = prototext의 네트워크로 학습 시킨 모델
# # 가중치와 바이어스가 담겨있음 
# # 일반적으로는 볼 수 없는 파일이지만 caffe 플랫폼으로는 개방해서 수정이 가능하다.
# weightsFile = "/Users/panhong/Desktop/openpose_sample/pose_iter_160000.caffemodel"
 
# # 위의 path에 있는 network 불러오기

# # 1번 인수는 .protext파일의 경로 
# # 2번 인수는 학습된 모델이 있는 .caffemodel파일의 경로
# # net은 변수이지만 의미가 있다.
# # net은 plaintext 모델링 언어(protext)로 정의된 레이어들과 그 연결들의 집합이다.
# # readNetFromCaffe = 네트워크를 불러오는 함수이다. 
# # opencv를 이용해서 딥러닝을 하기 위해서는 dnn_Net클래스 객체 생성이 필요한데
# # 객체 생성에는 훈련된 가중치와 네트워크 구성을 저장하고 있는 파일이 필요함
# net = cv2.dnn.readNetFromCaffe(protoFile, weightsFile)

# # opencv를 이용하여 이미지 읽어오기
# image = cv2.imread("/Users/panhong/Desktop/baseball/cropped.jpg")

# # frame.shape = 불러온 이미지에서 height, width, color 받아옴
# # 1 = 이미지의 높이 , 2 = 이미지의 너비 , 3 = 이미지의 채널
# imageHeight, imageWidth, _ = image.shape


# # network에 넣기위해 전처리
# # blob = 동일한 방식으로 전처리된 동일한 너비 , 높이 , 채널 수를 가진 하나 이상의 이미지
# # 변수 설명
# # image = 이미지 자체
# # 2 번째 인수 = 각 픽셀값의 배율을 지정해줌
# # 3 번째 인수 = 네트워크에 대한 기본 입력은 320 x 320임 따라서 blob를 만들려면 
# # 지정 할 필요가 있음 , 다른 차원 입력으로도 실험이 가능
# # size = 출력 영상의 크기(이 코드에서는 지정해놓은 weight , heigth의 값)
# # mean = 입력영상 각 채널에서 뺼 평균 값 , 기본값은 (0,0,0)
# # swapRB = R 과 B채널을 서로 바꿀것인지 결정하는 플래그 , 기본값은 False
# # 바꿀것인지 결정하는 이유는 opencv = bgr형식을 사용하지만 tensorflow = rgb형식을 사용하기 때문에 물어본것임
# # 마지막 매개변수는 이미지를 자르고 잘래낸 중심을 가질것이냐의 의미(???)
# # blob의 인자들을 입력할 때 모델 파일이 어떻게 학습되었는지 파악하고 그에 맞게 입력을 해주어여 함
# inpBlob = cv2.dnn.blobFromImage(image, 1.0 / 255, (imageWidth, imageHeight), (0, 0, 0), swapRB=False, crop=False)
 
# # network에 넣어주기
# # 가져온 이미지를 입력
# net.setInput(inpBlob)

# # 결과 받아오기
# # 매개변수를 입력해주지 않아서 해석하면 전체네트워크에 대해 
# # 정방향 전달을 실행
# # 상단에 blob를 통해서 이미지를 구성했고 
# # setInput을 이용해 net에다가 할당해주었다.
# # 그 이미지를 output변수가 가진것임 
# output = net.forward()

# # output.shape[0] = 이미지 ID, [1] = 출력 맵의 높이, [2] = 너비
# # H = height
# H = output.shape[2]
# # W = width
# W = output.shape[3]
# print("이미지 ID : ", len(output[0]), ", H : ", output.shape[2], ", W : ",output.shape[3]) # 이미지 ID

# # 키포인트 검출시 이미지에 그려줌
# points = []
# # 0 ~ 15 까지는 상단의 BODY_PARTS의 개수와 동일함
# for i in range(0,15):
#     # 해당 신체부위 신뢰도 얻음.
#     probMap = output[0, i, :, :]
     
#     # 템플릿 매칭 = 어떤 이미지에서 부분이미지를 검색하고 찾는 방법
#     # minMaxLoc함수를 이용해서 비교되는 이미지와의 최소 , 최대포인터 , 최소 , 최대 지점의 값을 받을 수 있다.
#     # 최소 포인터의 값을 이용해서 해당되는 부분과의 유사도가 가장 낮을때를 알 수 있다.
#     # 최대 포인터를 이용하면 자연스럽게 가장 유사도가 높은 부분을 알 수 있다.
#     # global 최대값 찾기 = 비교이미지와 가장 매칭도가 높은곳 찾기
#     minVal, prob, minLoc, point = cv2.minMaxLoc(probMap)

#     # 원래 이미지에 맞게 점 위치 변경
#     x = (imageWidth * point[0]) / W
#     y = (imageHeight * point[1]) / H
    
#     # 키포인트가 0.1이면 비교이미지와의 매치가 90% 이상이라는 뜻으로 
#     # 해당 부위에 BODY_PARTS의 number을 cv2.circle을 이용해서 점으로 찍어준다.
#     # 키포인트 검출한 결과가 0.1보다 크면(검출한곳이 위 BODY_PARTS랑 맞는 부위면) points에 추가, 검출했는데 부위가 없으면 None으로    
#     if prob > 0.1 :    
#         # circle(그릴곳, 원의 중심, 반지름, 색)
#         cv2.circle(image, (int(x), int(y)), 3, (0, 255, 255), thickness=-1, lineType=cv2.FILLED)       
#         # putText함수를 이용해서 먼저 점을 찍은다음에 매칭된지점에 알맞은 부위번호를 적어준다.
#         cv2.putText(image, "{}".format(i), (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1, lineType=cv2.LINE_AA)
#         # m
#         points.append((int(x), int(y)))
#     else :
#         points.append(None)

# # 점만 찍혀있는 이미지 출력
# cv2.imshow("Output-Keypoints",image)
# # waitKey를 이용해서 다음 이미지로 점프
# cv2.waitKey(0)

# # 이미지 복사
# imageCopy = image

# # 각 POSE_PAIRS별로 선 그어줌 (머리 - 목, 목 - 왼쪽어깨, ...)
# for pair in POSE_PAIRS:
#     partA = pair[0]             # Head
#     partA = BODY_PARTS[partA]   # 0
#     partB = pair[1]             # Neck
#     partB = BODY_PARTS[partB]   # 1
    
#     print(partA," 와 ", partB, " 연결\n")
#     # 두 part 모두 값이 할당이 되면 copy이미지에 라인을 그려줌
#     if points[partA] and points[partB]:
#         # img = 이미지 , points = 시작점 , 종료점 좌표 , color , 라인의 종류
#         cv2.line(imageCopy, points[partA], points[partB], (255, 0, 0), 2)

# # 라인이 그려진 이미지를 출력
# cv2.imshow("Output-Keypoints",imageCopy)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# cv2.waitKey(1)


# '''============================================================================================================================='''
# # 영상 스켈레톤 그리기 

# import cv2 as cv 
# import numpy as np
# import argparse
# import matplotlib.pyplot as plt

# net = cv.dnn.readNetFromTensorflow("/Users/panhong/Desktop/human-pose/graph_opt.pb")

# inWidht = 368
# inHeight = 368
# thr = 0.2

# BODY_PARTS = { "Nose": 0, "Neck": 1, "RShoulder": 2, "RElbow": 3, "RWrist": 4,
#                "LShoulder": 5, "LElbow": 6, "LWrist": 7, "RHip": 8, "RKnee": 9,
#                "RAnkle": 10, "LHip": 11, "LKnee": 12, "LAnkle": 13, "REye": 14,
#                "LEye": 15, "REar": 16, "LEar": 17, "Background": 18 }

# POSE_PAIRS = [ ["Neck", "RShoulder"], ["Neck", "LShoulder"], ["RShoulder", "RElbow"],
#                ["RElbow", "RWrist"], ["LShoulder", "LElbow"], ["LElbow", "LWrist"],
#                ["Neck", "RHip"], ["RHip", "RKnee"], ["RKnee", "RAnkle"], ["Neck", "LHip"],
#                ["LHip", "LKnee"], ["LKnee", "LAnkle"], ["Neck", "Nose"], ["Nose", "REye"],
#                ["REye", "REar"], ["Nose", "LEye"], ["LEye", "LEar"] ]

# cap = cv.VideoCapture("/Users/panhong/Desktop/baseball/오타니.mov")
# cap.set(3,800)
# cap.set(4,800)

# if not cap.isOpened():
#     cap = cv.VideoCapture(0)
# if not cap.isOpened():
#     raise IOError("Cannot open Video")
    
# while cv.waitKey(1) < 0:
#     hasFrame , frame = cap.read()
#     if not hasFrame:
#         cv.waitKey()
#         break
        
#     frameWidth = frame.shape[1]
#     frameHeight = frame.shape[0]
#     net.setInput(cv.dnn.blobFromImage(frame , 1.0 , (inWidht , inHeight) , (127.5 , 127.5 , 127.5) , swapRB = True , crop = False))
#     out = net.forward()
#     out = out[:, :19, :, :]  # MobileNet output [1, 57, -1, -1], we only need the first 19 elements

#     assert(len(BODY_PARTS) == out.shape[1])

#     points = []
    
#     for i in range(len(BODY_PARTS)):
#         # Slice heatmap of corresponging body's part.
#         heatMap = out[0, i, :, :]

#         # Originally, we try to find all the local maximums. To simplify a sample
#         # we just find a global one. However only a single pose at the same time
#         # could be detected this way.
#         _, conf, _, point = cv.minMaxLoc(heatMap)
#         x = (frameWidth * point[0]) / out.shape[3]
#         y = (frameHeight * point[1]) / out.shape[2]
#         # Add a point if it's confidence is higher than threshold.
#         points.append((int(x), int(y)) if conf > thr else None)

#     for pair in POSE_PAIRS:
#         partFrom = pair[0]
#         partTo = pair[1]
#         assert(partFrom in BODY_PARTS)
#         assert(partTo in BODY_PARTS)

#         idFrom = BODY_PARTS[partFrom]
#         idTo = BODY_PARTS[partTo]

#         if points[idFrom] and points[idTo]:
#             cv.line(frame, points[idFrom], points[idTo], (0, 255, 0), 3)
#             cv.ellipse(frame, points[idFrom], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)
#             cv.ellipse(frame, points[idTo], (3, 3), 0, 0, 360, (0, 0, 255), cv.FILLED)

#     t, _ = net.getPerfProfile()
#     freq = cv.getTickFrequency() / 1000
#     cv.putText(frame, '%.2fms' % (t / freq), (10, 20), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0))
    
#     cv.imshow("pose estimation Tutorial" , frame)

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import sys

# %%
# 모델을 로드해온 파일의 경로 
# https://tfhub.dev/google/lite-model/movenet/singlepose/lightning/3

# interpreter 변수를 생성해 다운로드 받았던 tflite모델의 경로를 입력해준다.
interpreter = tf.lite.Interpreter(model_path = "/Users/panhong/Downloads/lite-model_movenet_singlepose_lightning_3.tflite")

# interpreter내부의 텐서들을 초기화 시켜준다. 
# tflite를 사용하려면 꼭 설정해주어야 하는 구문이다.
interpreter.allocate_tensors()

# %%
plt.imshow(tf.cast(np.squeeze(img) , dtype = tf.int32))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rs/q3tvc3s53gbblf3cd1ncwv2c0000gn/T/ipykernel_99018/165665951.py in <module>
# ----> 1 plt.imshow(tf.cast(np.squeeze(img) , dtype = tf.int32))
#
# NameError: name 'img' is not defined

# %%
# cv2.VideoCapture 함수는 비디오파일의 경로를 입력해주면 비디오 파일을 열어서 motion_tracaking을 사용할수도 있고
# 본인의 컴퓨터에 웹캡이 존재한다면 경로가 들어가는 공간에 숫자 0을 넣어주면 
# 웹캠을 통해서 실시간으로 본인의 motion 또한 tracking을 할 수 있다.
cap = cv2.VideoCapture("/Users/panhong/Desktop/baseball/김진욱.mov")
# cap = cv2.VideoCapture(0)

# is.Opened함수를 사용해서 비디오 파일이 제대로 출력이 되고있는지 확인하는 함수이다.
while cap.isOpened():
    # 제대로 출력이 되고 있다면 자연스럽게 ret , frame 변수에 각각의 값이 할당이 될것이다.
    # 출력이 되었다면 ret = True가 되고 , frame은 영상의 이미지가 담긴다.
    ret , frame = cap.read()
    
    # 비디오 파일이 제대로 출력이 되고 있지 않다면 "영상이 올바르게 출력되지 않았습니다." 라는 문구를 출력하고 반복문을 종료한다.
    if not ret:
        print("영상이 올바르게 출력되지 않았습니다.")
        break
    
    # cap.get 함수와 cv2.CAP_PROP_FRAME_WIDTH , HEIGHT  , FPS 함수를 이용해서 
    # w , h , fps의 변수에 값을 할당
    # round함수는 입력받은 숫자를 반올림을 해줌
    # 실수형을 정수형으로 만들어 주기 위해서 사용 
    # fps함수는 입력되는 영상의 초당 frame수를 가져온다. (초당 프레임수란 영상이 1초당 출력하는 이미지의 개수를 뜻한다.)
    w = round(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    # 영상을 저장해주기 위해서 videowriter함수를 사용 
    # fourcc란 저장될 영상의 코덱을 의미함
    # 코덱이란 디지털 비디오와 오디오를 위한 압축/복원 기술을 의미함
    fourcc = cv2.VideoWriter_fourcc(*"DIVX")

    # 영상의 초당프레임수를 가져옴
    # delay의 결과가 30이라면 해당 영상의 초당 출력하는 
    # 이미지의 수는 30개란 뜻임
    delay = round(1000 / fps)
    
    # videowriter함수를 이용해서 out변수에 저장
    # 1.저장될 영상의 이름  2.코덱  3.초당 프레임  4.width , height
    out = cv2.VideoWriter('hello.avi', fourcc, fps, (w, h))
    
    # 색상이 반전된 영상출력
    inversed = ~frame # 반전

    # 윤관선만 인식하는 영상출력
    edge = cv2.Canny(frame, 50, 150)
    
    # 윤곽선은 그레이스케일 영상이므로 저장이 불가능 , 컬러영상으로 변경 후 저장
    edge_color = cv2.cvtColor(edge, cv2.COLOR_GRAY2BGR)
    
    # 영상의 데이터만 저장 , 소리는 x
    out.write(edge_color)

    # Reshape image (입력될 이미지를 재구성)
    # 모델을 가져온 링크를 타고 들어가면 해당 모델의 input값은 float32 , 192 * 192 * 3이므로 
    # 가져올 이미지나 비디오를 input모델에 맞게 새롭게 구성을 해주어야 한다.
    # 이것은 로드한 모델의 규칙이기 때문에 어겨서는 안된다.
    
    # 이미지 변수에 frame(cap에서 가져온 비디오의 frame).copy함수를 사용해서 값을 할당
    img = frame.copy()
    frame_2 = frame.copy()
    frame_2 = cv2.cvtColor(frame_2 , cv2.COLOR_BGR2GRAY)
    
    # tf.image.resize함수를 이용해서 이미지를 input값이 조건에 맞게 새롭게 설정해준다.
    # tf.image_resize함수는 조건에 맞게 이미지의 구조를 변경시켜주는 함수이다.
    # 첫번째 인자가 image인데 차원확장을 시켜주는 np.expand_dims함수를 이용해서 img의 차원을 변경시켜준다.
    # axis = 0이므로 예를 들어 차원이 (4 , 3 , 2)였다면 (1 , 4 , 3 , 2)으로 차원을 1차원 더 늘려준다.
    # 두번쨰 인자는 이미지의 weight , heigth값을 설정해주어야 하는데 각각 192 , 192 차원으로 설정을 해서 조건에 맞추어 주었다.
    img = tf.image.resize_with_pad(np.expand_dims(img , axis = 0) , 192 , 192)
    
    # 텐서를 새로운 형태로 casing해주는 tf.cast함수 
    # 첫번째 인자를 입력으로 하고 두번째 인자를 이용해서 첫번쨰 인자의 구조를 바꾸어 준다.
    # 현재 같은 경우는 img(frame.copy)를 소주점형태로 변환을 시켜주었다.
    # cast같은 경우는 로그함수를 사용해서 분석을 할때도 사용했었는데 어떠한 조건이 없는걸로 보아서는 
    # True , False로 출력하는 것이 아니라 1 , 0으로 실수형태로 출력이 될것같다.
    input_image = tf.cast(img , dtype = tf.float32)
     
    # Setup input and output
    # 가져온 모델(상단의 interpreter)의 입력과 출력의 세부 정보를 가져오는 함수이다.
    # tflite모델을 사용할때는 코드를 작성하기 이전에 먼저 이렇게 입력과 출력의 세부사항을 찍어서 확인한 다음에
    # 코드를 작성하는것이 좋다. (강조)
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    
    # Make predictions
    # 입력 세부 정보를 입력 이미지와 동일하게 설정
    interpreter.set_tensor(input_details[0]["index"] , np.array(input_image))
    
    # 예측을 호출(?) 하고
    # invoke를 호출함으로서 마지막함수인 interpreter.get_tensor의 값을 가져올수 있다.
    # 이 값은 표현하자면 이미지나 영사에서 감지된 관절의 위치 좌표와 탐색해서 나온결과의 신뢰도 세트를 출력해준다.
    # 좌표와 신뢰도 세트는 [0.28992683, 0.37796742, 0.39410055] 이렇게 요소가 총 3개인 리스트로 출력이 된다.
    # 그리고 이 데이터세트가 어떤 관절부위를 나타내는지 알 수 있는 방법은 모델을 가져온 페이지에서 확인할 수 있다.
    interpreter.invoke()
    
    # 출력 세부정보를 얻어온다. (1 , 1, 17 , 3)으로 이루어진 탐색된 관절의 좌표와 신뢰도세트
    keypoints_with_scores = interpreter.get_tensor(output_details[0]["index"])
    print(keypoints_with_scores)
    
    
    # Rendering(frame에 motion_tracking 적용)
    
    # 해당 함수는 아래 작성을 했던 draw_keypoints함수이다. 
    # 필요한 인자로는 점이 찍힐 이미지 , 점을 찍을 좌표 , 탐색한 관절위치에 대한 신뢰도로 구성이 되어있다.
    # 신뢰도를 0.4로 지정해준 이유는 아래의 데이터셋에서 확인해보았을때 평균적으로 0.4이상이었기때문에 
    # 0.4로 지정을 해주었다.(너무 정확하게 관절의 위치를 표현하고자 신뢰도 진입장벽을 높게 잡아버리면 아예 관절의 위치가 나오지 않는경우도 생긴다.)
    
    # 색상 영상  
    draw_keypoints(frame , keypoints_with_scores , 0.4)
    draw_keypoints(inversed , keypoints_with_scores , 0.4)
    
    
    # 흑백 영상(흑백은 채널이 없기때문에 기존에 함수를 수정해서 사용해주었다.)
    draw_keypoints_black(frame_2 , keypoints_with_scores , 0.4)
    draw_keypoints_black(edge , keypoints_with_scores , 0.4)
    
    
    # 해당함수는 아래 작성을 했던 draw_connections함수이다. 
    # 인자들의 구성은 key_points함수와 같지만 EDGES가 추가되어 있다.
    # 자세한 설명을 아래로 가면 볼 수 있다.
    
    # 색상 영상 
    draw_connections(frame , keypoints_with_scores , EDGES , 0.4)
    draw_connections(inversed , keypoints_with_scores , EDGES , 0.4)
    
    # 흑백 영상(흑백은 채널이 없기때문에 기존에 함수를 수정해서 사용해주었다.)
    draw_connections_black(frame_2 , keypoints_with_scores , EDGES , 0.4)
    draw_connections_black(edge , keypoints_with_scores , EDGES , 0.4)
    
    
    # 위의 모든 구문이 통과가 되면 cv2.imshow함수를 사용해 윈도우의 이름은 첫번째 인자로 지정해주고 , 두번째 인자인
    # frame를 출력해준다.
    cv2.imshow("Movenet Lighting" , frame)
    cv2.imshow("black" , frame_2)
    cv2.imshow('inversed', inversed)
    cv2.imshow('edge', edge)
    
    width = cap.get(3)
    height = cap.get(4)
    
    print(width)
    print(height)
            
    # 키보드 이벤트를 설정해준다. 키보드에서 q를 누르면 반복문을 종료하고 모든 윈도우를 제거 해준다.
    if cv2.waitKey(1) & 0xFF == 27:
        break
        
# open한 cap객체를 release함수를 실행해서 반드시 종료시켜준다.
cap.release()
out.release()
cv2.waitKey()
cv2.destroyAllWindows()
cv2.waitKey(1)
cv2.waitKey(1)
cv2.waitKey(1)
cv2.waitKey(1)
# Out:
# [[[[0.15466374 0.5802514  0.52161014]
#    [0.13828696 0.5664445  0.49960792]
#    [0.14000818 0.56801224 0.56249386]
#    [0.150992   0.5193769  0.5120953 ]
#    [0.15456246 0.5251347  0.691369  ]
#    [0.22658561 0.4864957  0.6154432 ]
#    [0.25393948 0.5183948  0.6352457 ]
#    [0.35986435 0.5439102  0.34796214]
#    [0.38373598 0.55698717 0.59292567]
#    [0.2901926  0.633022   0.2563444 ]
#    [0.30712536 0.6415552  0.3573051 ]
#    [0.49217218 0.46562803 0.7031878 ]
#    [0.49790072 0.49705502 0.6651396 ]
#    [0.65769553 0.49466974 0.61004883]
#    [0.66692924 0.5469986  0.75278264]
#    [0.8183236  0.39607817 0.54468787]
#    [0.86377656 0.5258361  0.5961169 ]]]]
# 608.0
# 794.0
# [[[[0.15460837 0.58061606 0.54057896]
#    [0.1385805  0.5671875  0.5342012 ]
#    [0.13983433 0.5675576  0.5646227 ]
#    [0.15082154 0.5202481  0.4941167 ]
#    [0.15493079 0.5246186  0.6747575 ]
#    [0.22777963 0.49122903 0.61907405]
#    [0.25045523 0.517233   0.6696367 ]
#    [0.3563646  0.54597306 0.36506736]
#    [0.3800316  0.5595082  0.5606335 ]
#    [0.29219562 0.6364119  0.30125713]
#    [0.30585703 0.6488509  0.5861365 ]
#    [0.49205598 0.46705055 0.7041425 ]
#    [0.49644563 0.49700087 0.6438532 ]
#    [0.65844446 0.49682695 0.60714686]
#    [0.6669247  0.5462954  0.75172555]
#    [0.81666815 0.3974669  0.5155982 ]
#    [0.8623676  0.52127564 0.67507744]]]]
# 608.0
# 794.0
# [[[[0.15459558 0.58064693 0.5402568 ]
#    [0.13857873 0.56719947 0.53478867]
#    [0.13984254 0.56760716 0.5659529 ]
#    [0.27416417 0.35892174 0.48799688]
#    [0.25622883 0.41864952 0.49217921]
#    [0.28491333 0.34925717 0.43671238]
#    [0.30270547 0.47329506 0.66161317]
#    [0.37800646 0.3751796  0.5089854 ]
#    [0.37521106 0.49444985 0.18461612]
#    [0.49505162 0.4126498  0.56412536]
#    [0.3687584  0.4062774  0.22700188]
#    [0.46729374 0.4006909  0.14095587]
#    [0.4956755  0.6188892  0.57727605]
#    [0.5272703  0.52992004 0.71287704]
#    [0.6976561  0.6331079  0.7184552 ]
#    [0.69783115 0.5392385  0.5337092 ]
#    [0.8123858  0.6068199  0.73528254]
#    [0.89084643 0.52097243 0.5248846 ]]]]
# 608.0
# 794.0
# 영상이 올바르게 출력되지 않았습니다.
# -1

# %%
inversed.shape
# Out:
# (794, 608, 3)

# %%
# input데이터의 입력세부 구조를 확인
# input = 입력구조
# 항상 이렇게 먼저 입력구조에 대해서 설정확인을 하고 난 다음 
# 입력될 자료의 구조를 조건에 맞게 설정을 해주고 코드 작성을 시작하는 것이 좋다.
interpreter.get_input_details()
# Out:
# [{'name': 'serving_default_input:0',
#   'index': 0,
#   'shape': array([  1, 192, 192,   3], dtype=int32),
#   'shape_signature': array([  1, 192, 192,   3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}}]

# %%
# output데이터의 내부구조를 확인 
# output = 출력구조 
# 입력조건에 맞추어서 데이터를 입력해주고 나서 출력은
# 항상 로드한 모델의 출력조건과 동일하게 출력이 된다.
# 현재 모델같은 경우는 출력의 shape는 ([1 , 1  , 17 , 3])으로 출력이된다.
interpreter.get_output_details()
# Out:
# [{'name': 'StatefulPartitionedCall:0',
#   'index': 312,
#   'shape': array([ 1,  1, 17,  3], dtype=int32),
#   'shape_signature': array([ 1,  1, 17,  3], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}}]

# %%
# 실제 출력이된 결과를 가져와서 확인해보기
# 확인해보면 모델의 출력조건과 동일하게 (1 , 1 , 17 , 3) dtype = float32로 출력이 되는것을 확인할수 있다.
# 데이터셋의 3번째 요소가 탐색한 관절위치의 신뢰도를 나타내는데 예를 들어 이미지가 정면만 보일경우에는 
# 데이터셋 마지막 8개의 데이터셋의 신뢰도는 현저하게 낮아진다. 그럴수밖에 없는것이 마지막 8개의 데이터세트는 
# 신체의 후면을 탐지하기 때문에 당연히 정면만 보이는 이미지에서는 신뢰도가 당연히 낮아질수 밖에 없으니 
# 혹여나 신뢰도가 너무 낮게 출력이 되었다면 이미지가 정면밖에 보이지 않는것은 아닌지 확인해볼 필요성이 있다.
keypoints_with_scores
# Out:
# array([[[[0.28992683, 0.37796742, 0.39410055],
#          [0.26168537, 0.3909939 , 0.60562253],
#          [0.27416417, 0.35892174, 0.48799688],
#          [0.25622883, 0.41864952, 0.49217921],
#          [0.28491333, 0.34925717, 0.43671238],
#          [0.30270547, 0.47329506, 0.66161317],
#          [0.37800646, 0.3751796 , 0.5089854 ],
#          [0.37521106, 0.49444985, 0.18461612],
#          [0.49505162, 0.4126498 , 0.56412536],
#          [0.3687584 , 0.4062774 , 0.22700188],
#          [0.46729374, 0.4006909 , 0.14095587],
#          [0.4956755 , 0.6188892 , 0.57727605],
#          [0.5272703 , 0.52992004, 0.71287704],
#          [0.6976561 , 0.6331079 , 0.7184552 ],
#          [0.69783115, 0.5392385 , 0.5337092 ],
#          [0.8123858 , 0.6068199 , 0.73528254],
#          [0.89084643, 0.52097243, 0.5248846 ]]]], dtype=float32)

# %%
# [nose, left eye, right eye, left ear, right ear, left shoulder, right shoulder, left elbow, right elbow, left wrist, right wrist, left hip, 
# right hip, left knee, right knee, left ankle, right ankle]).
# 상단에 표시된 리스트가 바로 마지막 출력이된(keypoints_with_scores)의 데이터세트와 연결지을수 있는 리스트이다.
# 상단의 리스트도 총 17개의 객체로 구성되어 있으며 최종출력결과또한 2차원인 요소가 17개가 있다.
# 각각 짝을 맞춰 주자면 최종출력결과의 0번째 리스트는 코의 좌표와 신뢰도를 나타내고 5번째 리스트는 좌측어깨의 좌표와 신뢰도를 나타낸다.

# 탐색된 좌측어깨의 x , y 좌표와 신뢰도 , # 탐색된 우측어깨의 x , y 좌표와 신뢰도
left_sholder = keypoints_with_scores[0][0][5]
right_sholder = keypoints_with_scores[0][0][7]

# %%
left_sholder , right_sholder
# Out:
# (array([0.30270547, 0.47329506, 0.66161317], dtype=float32),
#  array([0.37521106, 0.49444985, 0.18461612], dtype=float32))

# %%
# 곱해준 480 , 640은 튜토리얼을 인용한것이고 원래 곱해주어야 하는값은 frame.shape의  w , h값을 곱해주어야한다.
# 일단 이렇게 표현을 한 이유는 [:2]번까지가 x , y의 좌표이며 int로 나타내주어서 횔씬 시각적으로 인식하기 편하게 해주기 위함이다.
np.array(left_sholder[:2] * [608 , 794]).astype(int)
# Out:
# array([184, 375])

# %%
# 좌표위치를 파악해서 해당되는 관절의 점을 찍어줄 함수작성 
# 점을 찍어주기 위해서 필요한 구성요소들은 (1.점이 찍힐 이미지  2.이미지에 점을 찍을 좌표 , 3.적절한 신뢰도)이다.
def draw_keypoints(frame , keypoints , confidence_threshold):
    # frame은 이미지이고 이미지를 shape를 하면 heigth , weigth , chnnel(흑 , 색)정보가 출력되고
    # 각각의 변수에다 해당되는 값을 할당해줄것이다.
    y , x , c = frame.shape
    
    # 해당 변수의 대한 설명은 바로 아래셀에서 볼수있다.
    shaped = np.squeeze(np.multiply(keypoints , [y , x , 1]))
    
    # shaped값을 kp에 입력
    # shaped의 값은 총 17개이기때문에 반복문을 이용해서 모든값을 적용하여 온전하게 점을 찍을수 있도록 해준다. 
    for kp in shaped:
        # shaped의 값을 입력받은 kp의 값을 다시 kx , ky , kp_conf에 개별로 값을 할당시켜준다.
        ky , kx , kp_conf = kp
        # kp_conf = 신뢰도 confidence = 작성자가 임의로 설정한 신뢰도 기준치
        # 신뢰도가 기준치보다 높다면 조건문을 실행
        if kp_conf > confidence_threshold:
            # cv2.circle는 원을 그려주는 cv2의 함수이다. 
            # 인수를 설명하자면 
            # 1. 원이 그려질 이미지 
            # 2. 원을 찍을 좌표
            # 2-1 shaped의 설명을 보면 왜 int를 씌워준지 이해를 할수가 있는데 int로 형변환을 시켜주면 보다 정확하게 
            # x , y 의 좌표를 가져올수 있기때문에 int로 형변환을 해준것이다.
            # 3. 원의 크기를 설정 
            # 4. 원의 색을 설정 
            # 5. 원의 선의 두께 (음수를 입력하게 되면 4에서 지정한 색으로 원을 채워주게 된다.)
            cv2.circle(frame , (int(kx) , int(ky))  , 4 , (0 , 255 , 0) , -1)

# %%
# 좌표위치를 파악해서 해당되는 관절의 점을 찍어줄 함수작성 
# 점을 찍어주기 위해서 필요한 구성요소들은 (1.점이 찍힐 이미지  2.이미지에 점을 찍을 좌표 , 3.적절한 신뢰도)이다.
def draw_keypoints_black(frame , keypoints , confidence_threshold):
    # frame은 이미지이고 이미지를 shape를 하면 heigth , weigth , chnnel(흑 , 색)정보가 출력되고
    # 각각의 변수에다 해당되는 값을 할당해줄것이다.
    y , x = frame.shape
    
    # 해당 변수의 대한 설명은 바로 아래셀에서 볼수있다.
    shaped = np.squeeze(np.multiply(keypoints , [y , x , 1]))
    
    # shaped값을 kp에 입력
    # shaped의 값은 총 17개이기때문에 반복문을 이용해서 모든값을 적용하여 온전하게 점을 찍을수 있도록 해준다. 
    for kp in shaped:
        # shaped의 값을 입력받은 kp의 값을 다시 kx , ky , kp_conf에 개별로 값을 할당시켜준다.
        ky , kx , kp_conf = kp
        # kp_conf = 신뢰도 confidence = 작성자가 임의로 설정한 신뢰도 기준치
        # 신뢰도가 기준치보다 높다면 조건문을 실행
        if kp_conf > confidence_threshold:
            # cv2.circle는 원을 그려주는 cv2의 함수이다. 
            # 인수를 설명하자면 
            # 1. 원이 그려질 이미지 
            # 2. 원을 찍을 좌표
            # 2-1 shaped의 설명을 보면 왜 int를 씌워준지 이해를 할수가 있는데 int로 형변환을 시켜주면 보다 정확하게 
            # x , y 의 좌표를 가져올수 있기때문에 int로 형변환을 해준것이다.
            # 3. 원의 크기를 설정 
            # 4. 원의 색을 설정 
            # 5. 원의 선의 두께 (음수를 입력하게 되면 4에서 지정한 색으로 원을 채워주게 된다.)
            cv2.circle(frame , (int(kx) , int(ky))  , 4 , (0 , 255 , 0) , -1)

# %%
# 상단의 함수에 shaped에 할당되어 있는 식을 전개하면 이런형태가 나오게 된다.
# 해석을 하면 우리는 점을 찍을 좌표가 보다 정확하게 입력이 되었으면 하기때문에 출력된 좌표값에 기존의 이미지의 x , y 좌표를
# np.multiply 함수를 이용하여 곱해준다. 이렇게 되면 결과가 기계나 사람이 보기에도 횔씬 더 정확하게 판단할수 있는 값이 출력이 나오게 된다.
# 마지막에 1을 곱해준 이유는 최종출력에서 좌표와 신뢰도가 출력된다고 했는데 마지막 신뢰도 값에 변화를 주지 않고 그대로 출력을 시키고자
# 1을 곱해준것이다.
np.squeeze(np.multiply(interpreter.get_tensor(interpreter.get_output_details()[0]["index"]) , [480 , 640 , 1]))

# [0]번째 배열을 출력하게되면 보다 깔끔하게 출력되는 결과를 볼수있다.(0번째 배열이 나타내는 것은 코의 좌표와 신뢰도)
# np.squeeze(np.multiply(interpreter.get_tensor(interpreter.get_output_details()[0]["index"]) , [480 , 640 , 1]))[0]

# 이렇게 마지막에 int로 형변환을 해주면 좌표의 값은 횔씬 정확하게 출력을 해줄수가 있겠지만 
# 마지막 신뢰도는 그대로 실수형이기 때문에 신뢰도가 0으로 출력이 된다. 그렇기때문에 
# int로 형변환을 해주지 않고 기존 이미지의 shape값만 곱해주는것이다.
# np.squeeze(np.multiply(interpreter.get_tensor(interpreter.get_output_details()[0]["index"]) , [480 , 640 , 1])).astype(int)
# Out:
# array([[1.39164877e+02, 2.41899147e+02, 3.94100547e-01],
#        [1.25608978e+02, 2.50236092e+02, 6.05622530e-01],
#        [1.31598802e+02, 2.29709911e+02, 4.87996876e-01],
#        [1.22989841e+02, 2.67935696e+02, 4.92179215e-01],
#        [1.36758399e+02, 2.23524590e+02, 4.36712384e-01],
#        [1.45298624e+02, 3.02908840e+02, 6.61613166e-01],
#        [1.81443100e+02, 2.40114937e+02, 5.08985400e-01],
#        [1.80101309e+02, 3.16447906e+02, 1.84616119e-01],
#        [2.37624779e+02, 2.64095879e+02, 5.64125359e-01],
#        [1.77004037e+02, 2.60017529e+02, 2.27001876e-01],
#        [2.24300995e+02, 2.56442184e+02, 1.40955865e-01],
#        [2.37924242e+02, 3.96089096e+02, 5.77276051e-01],
#        [2.53089752e+02, 3.39148827e+02, 7.12877035e-01],
#        [3.34874926e+02, 4.05189056e+02, 7.18455195e-01],
#        [3.34958954e+02, 3.45112648e+02, 5.33709228e-01],
#        [3.89945183e+02, 3.88364754e+02, 7.35282540e-01],
#        [4.27606287e+02, 3.33422356e+02, 5.24884582e-01]])

# %%
# 해당 딕셔너리를 이용해서 그려진 점들을 선으로 연결시켜주는데 도움을 줄 수가 있다.
# 가만히 보면 key부분에는 (0 , 1)이런형식으로 작성이 되어있는데 여기서 나타내는 숫자는 
# 각 관절의 위치번호이며 튜플로 묶어져있는 관절의 위치를 라인으로 그려주라는 가이드라고 생각하면 좋을것 같다.
# 실제로 관절번호중 0 = 코 , 1 = 좌측안구이며 코에 그려진 원과 좌측안구에 그려진 원을 연결한다.
# 아래의 튜플들도 각각 자연스러운 연결을 위해서 적합한 관절끼리 튜플형식으로 묶여져 있다.
EDGES = {
    (0, 1): 'm',
    (0, 2): 'c',
    (1, 3): 'm',
    (2, 4): 'c',
    (0, 5): 'm',
    (0, 6): 'c',
    (5, 7): 'm',
    (7, 9): 'm',
    (6, 8): 'c',
    (8, 10): 'c',
    (5, 6): 'y',
    (5, 11): 'm',
    (6, 12): 'c',
    (11, 12): 'y',
    (11, 13): 'm',
    (13, 15): 'm',
    (12, 14): 'c',
    (14, 16): 'c'
}

# %%
# 상단의 draw_keypoints와 거의 유사하지만 매개변수에 edges라는 변수가 추가되었다.
# 이 함수는 관절에 그려진 원들을 각각 라인으로 연결시켜주기 위해서 작성한 함수이다.
def draw_connections(frame , keypoints , edges , confidence_threshold):
    # 아래 2줄은 key_points의 함수와 100%같은 코드이다.
    y , x , c = frame.shape 
    shaped = np.squeeze(np.multiply(keypoints , [y , x , 1]))
    
    # edges.items = 상단에 보이는 딕셔너리를 할당해 줄것이다.
    # 그렇게되면 edge에는 key가 들어갈것이며 , color에는 values가 할당될것이다.
    # color의 내용은 사용하지 않았다.
    for edge , color in edges.items():
        # edge의 값은 2개이므로 각각의 값을 p1 , p2로 찢어준다.
        p1 , p2 = edge
        # shaped값은 상단에 설명이 되어었고 p1 , p2의 값은 관절위치의 정보이므로 
        # shaped내에서 p1 , p2에 적용되는 자료들을 불러와 할당을 해줄것이다. 
        # 자료들은 좌표와 신뢰도이다.
        y1 , x1 , c1 = shaped[p1]
        y2 , x2 , c2 = shaped[p2]
        
        # c1 , c2(EDGES에서 명령한 관절위치의 대한 신뢰도)가 각각 지정해놓은 신뢰도 수치보다 높다면 조건문 실행
        if(c1 > confidence_threshold) & (c2 > confidence_threshold):
            # cv2의 그리기 함수 
            # 1. 라인이 그려질 이미지 
            # 2. 직선의 시작점과 끝점
            # 3. 선의 색상
            # 4. 선의 두께
            cv2.line(frame , (int(x1) , int(y1))  , (int(x2) , int(y2)) , (255 , 0 , 0)  , 2)

# %%
# 상단의 draw_keypoints와 거의 유사하지만 매개변수에 edges라는 변수가 추가되었다.
# 이 함수는 관절에 그려진 원들을 각각 라인으로 연결시켜주기 위해서 작성한 함수이다.
def draw_connections_black(frame , keypoints , edges , confidence_threshold):
    # 아래 2줄은 key_points의 함수와 100%같은 코드이다.
    y , x = frame.shape 
    shaped = np.squeeze(np.multiply(keypoints , [y , x , 1]))
    
    # edges.items = 상단에 보이는 딕셔너리를 할당해 줄것이다.
    # 그렇게되면 edge에는 key가 들어갈것이며 , color에는 values가 할당될것이다.
    # color의 내용은 사용하지 않았다.
    for edge , color in edges.items():
        # edge의 값은 2개이므로 각각의 값을 p1 , p2로 찢어준다.
        p1 , p2 = edge
        # shaped값은 상단에 설명이 되어었고 p1 , p2의 값은 관절위치의 정보이므로 
        # shaped내에서 p1 , p2에 적용되는 자료들을 불러와 할당을 해줄것이다. 
        # 자료들은 좌표와 신뢰도이다.
        y1 , x1 , c1 = shaped[p1]
        y2 , x2 , c2 = shaped[p2]
        
        # c1 , c2(EDGES에서 명령한 관절위치의 대한 신뢰도)가 각각 지정해놓은 신뢰도 수치보다 높다면 조건문 실행
        if(c1 > confidence_threshold) & (c2 > confidence_threshold):
            # cv2의 그리기 함수 
            # 1. 라인이 그려질 이미지 
            # 2. 직선의 시작점과 끝점
            # 3. 선의 색상
            # 4. 선의 두께
            cv2.line(frame , (int(x1) , int(y1))  , (int(x2) , int(y2)) , (255 , 0 , 0)  , 2)

# %%
# draw_connection 함수내에 for문 설명
# 아래처럼 for문을 작성하면 shaped에 있는 값들이 각각 변수들에 할당이 되어 
# 정확하게 라인을 그릴수 있도록 도움을 준다. 
for edge , color in EDGES.items():
    p1 , p2 = edge 
    y1 , x1 , c1 = shaped[p1]
    y2 , x2 , c2 = shaped[p2]
    print(y1 , x1 , c1 , y2 , x2 , c2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rs/q3tvc3s53gbblf3cd1ncwv2c0000gn/T/ipykernel_99018/4207389617.py in <module>
#       2 # 아래처럼 for문을 작성하면 shaped에 있는 값들이 각각 변수들에 할당이 되어
#       3 # 정확하게 라인을 그릴수 있도록 도움을 준다.
# ----> 4 shaped = np.squeeze(np.multiply(keypoints , [y , x , 1]))
#       5
#       6 for edge , color in EDGES.items():
#
# NameError: name 'keypoints' is not defined
