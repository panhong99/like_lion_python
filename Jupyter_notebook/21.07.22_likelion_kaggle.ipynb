# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import seaborn as sns
import re
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.models import  Sequential
from tensorflow.keras.layers import Dense 
from tensorflow.keras.callbacks import ModelCheckpoint , EarlyStopping
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

train_data = pd.read_csv("/Users/panhong/Desktop/coding_study/Likelion_KDT/Jupyter_notebook/csv_file/train.csv")

test_data = pd.read_csv("/Users/panhong/Desktop/coding_study/Likelion_KDT/Jupyter_notebook/csv_file/test.csv")

# 먼저 결측치 확인 
train_data.isna().sum()

# 결측치를 해당 컬럼의 평균으로 대체
train_data["Age"] = train_data["Age"].fillna(train_data["Age"].mean())
test_data["Age"] = test_data["Age"].fillna(test_data["Age"].mean())

# train_data["Age"]

# 라벨인코더를 위해서 data에서 pop
name = train_data.pop("Name")
sex = train_data.pop("Sex")
embarked = train_data.pop("Embarked")
survived_cloen = train_data.pop("Survived")

# ticket같은 경우도 문자열과 혼합이 되어있기때문에 
# 마지막 숫자만 끌어와서 np.array로 변형시켜주고 
# data에 추가시킨다.
ticket_cloen = train_data.pop("Ticket")
ticket_cloen = list(ticket_cloen)

ticket_save = []

for i in ticket_cloen:
    ticket_save.append(i[-1])
save_ticket = np.array(ticket_save)

# cabin같은 경우는 결측치도 많고 슬라이싱도 해주어야 해서 
# fillna함수로 결측치를 삭제시켜주고 첫글자만 슬라이싱을 해줌
# 그리고서 라벨인코딩 후 data에 추가

cabin_save = train_data.pop("Cabin")
cabin_save = cabin_save.fillna(method = "pad")
cabin_save = cabin_save.fillna("C85")

save_cabin = []

for i in range(len(cabin_save)):
    save_cabin.append(cabin_save[i][:1])
cabin_cloen = np.array(save_cabin)

# 라벨 인코딩 시작 
e1 = LabelEncoder()
e1.fit(name)
name = e1.transform(name)

e2 = LabelEncoder()
e2.fit(sex)
sex = e2.transform(sex)

e3 = LabelEncoder()
e3.fit(embarked)
embarked = e3.transform(embarked)

e4 = LabelEncoder()
e4.fit(cabin_cloen)
cabin = e4.transform(cabin_cloen)

e5 = LabelEncoder()
e5.fit(save_ticket)
ticket = e5.transform(save_ticket)

# 인코딩을 마치고 data에 설정
train_data["Ticket"] = ticket
train_data["Cabin"] = cabin
train_data["Name"] = name
train_data["Sex"] = sex
train_data["Embarked"] = embarked
train_data["Survived"] = survived_cloen

# 데이터의 밸류들만 가져와서 dataset 변수에 저장 
# 아래 구문부터는 너무나도 익숙한 케라스의 기본 모델이기때문에
# 자세한 설명은 하지않겠음
dataset = train_data.values
x_data = dataset[: , :11]
y = dataset[: , 11]

y_data = tf.keras.utils.to_categorical(y)

# %%
train_data = pd.read_csv("/Users/panhong/Desktop/coding_study/Likelion_KDT/Jupyter_notebook/csv_file/train.csv")

test_data = pd.read_csv("/Users/panhong/Desktop/coding_study/Likelion_KDT/Jupyter_notebook/csv_file/test.csv")

# 먼저 결측치 확인 
# train_data.isna().sum()

# 결측치를 해당 컬럼의 평균으로 대체
# train_data["Age"] = train_data["Age"].fillna(train_data["Age"].mean())
test_data["Age"] = test_data["Age"].fillna(test_data["Age"].mean())
# train_data["Age"]

# 라벨인코더를 위해서 data에서 pop
name_test = test_data.pop("Name")
sex_test = test_data.pop("Sex")
embarked_test = test_data.pop("Embarked")
# survived_cloen_test = test_data.pop("Survived")

ticket_cloen_test = test_data.pop("Ticket")
ticket_cloen_test = list(ticket_cloen_test)

ticket_save_test = []

for i in ticket_cloen_test:
    ticket_save_test.append(i[-1])
save_ticket_test = np.array(ticket_save_test)

# cabin같은 경우는 결측치도 많고 슬라이싱도 해주어야 해서 
# fillna함수로 결측치를 삭제시켜주고 첫글자만 슬라이싱을 해줌
# 그리고서 라벨인코딩 후 data에 추가

cabin_save_test = test_data.pop("Cabin")
cabin_save_test = cabin_save_test.fillna(method = "pad")
cabin_save_test = cabin_save_test.fillna("C85")

save_cabin_test = []

for i in range(len(cabin_save_test)):
    save_cabin_test.append(cabin_save_test[i][:1])
cabin_cloen_test = np.array(save_cabin_test)

e1 = LabelEncoder()
e1.fit(name_test)
name_test_data = e1.transform(name_test)

e2 = LabelEncoder()
e2.fit(sex_test)
sex_test = e2.transform(sex_test)

e3 = LabelEncoder()
e3.fit(embarked_test)
embarked_test = e3.transform(embarked_test)

e4_test = LabelEncoder()
e4_test.fit(cabin_cloen_test)
cabin_test = e4_test.transform(cabin_cloen_test)

e5_test = LabelEncoder()
e5_test.fit(save_ticket_test)
ticket_test = e5.transform(save_ticket_test)

test_data["Ticket"] = ticket_test
test_data["Cabin"] = cabin_test
test_data["Name"] = name_test_data
test_data["Sex"] = sex_test
test_data["Embarked"] = embarked_test
test_data["Survived"] = survived_cloen_test

# 결측치 삭제
test_data = test_data.dropna()

dataset_test = test_data.values
x_test = dataset_test[: , :11]

# %%
model = Sequential()
model.add(Dense(30 , input_dim = 11 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(30 , activation = "relu"))
model.add(Dense(2 , activation = "softmax"))

model.compile(loss = "categorical_crossentropy" , optimizer = optimizers.Adam(lr = 0.001) , metrics = ["accuracy"])

model_dir = "./model_titanic/"
if not os.path.exists(model_dir):
    os.mkdir(model_dir)
modelpath = "./model_titanic/{epoch:02d}-{accuracy:.4f}.hdf5"

checkpoint = ModelCheckpoint(filepath = modelpath , mointor = "accuracy" , verbose = 1 , save_best_only = True)

earlystopping = EarlyStopping(monitor = "accuracy" , patience = 100)

model.fit(x_data , y_data , epochs = 2000 , verbose = 1 , validation_split = 0.33 , batch_size = 10 , callbacks = [checkpoint , earlystopping])
model.summary()
prediction = model.predict(x_test).flatten()

print("데이터 : {}".format(prediction))
print("\nAccuracy %.4f" %(model.evaluate(x_data ,y_data)[1]))
# Out:
# Epoch 1/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 1.2103 - accuracy: 0.5604 - val_loss: 0.6323 - val_accuracy: 0.6508
#
# Epoch 00001: val_loss improved from inf to 0.63234, saving model to ./model_titanic/01-0.5604.hdf5
# Epoch 2/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6820 - accuracy: 0.5789 - val_loss: 0.6507 - val_accuracy: 0.6441
#
# Epoch 00002: val_loss did not improve from 0.63234
# Epoch 3/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6658 - accuracy: 0.6292 - val_loss: 0.6316 - val_accuracy: 0.6508
#
# Epoch 00003: val_loss improved from 0.63234 to 0.63158, saving model to ./model_titanic/03-0.6292.hdf5
# Epoch 4/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6994 - accuracy: 0.5738 - val_loss: 0.6380 - val_accuracy: 0.6441
#
# Epoch 00004: val_loss did not improve from 0.63158
# Epoch 5/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6916 - accuracy: 0.5570 - val_loss: 0.6099 - val_accuracy: 0.6814
#
# Epoch 00005: val_loss improved from 0.63158 to 0.60986, saving model to ./model_titanic/05-0.5570.hdf5
# Epoch 6/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6759 - accuracy: 0.6074 - val_loss: 0.6244 - val_accuracy: 0.6949
#
# Epoch 00006: val_loss did not improve from 0.60986
# Epoch 7/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6580 - accuracy: 0.6359 - val_loss: 0.6093 - val_accuracy: 0.6983
#
# Epoch 00007: val_loss improved from 0.60986 to 0.60935, saving model to ./model_titanic/07-0.6359.hdf5
# Epoch 8/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6496 - accuracy: 0.6409 - val_loss: 0.7723 - val_accuracy: 0.6576
#
# Epoch 00008: val_loss did not improve from 0.60935
# Epoch 9/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6564 - accuracy: 0.6477 - val_loss: 0.6342 - val_accuracy: 0.7017
#
# Epoch 00009: val_loss did not improve from 0.60935
# Epoch 10/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6616 - accuracy: 0.6208 - val_loss: 0.6404 - val_accuracy: 0.6542
#
# Epoch 00010: val_loss did not improve from 0.60935
# Epoch 11/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6596 - accuracy: 0.6208 - val_loss: 0.6003 - val_accuracy: 0.6915
#
# Epoch 00011: val_loss improved from 0.60935 to 0.60031, saving model to ./model_titanic/11-0.6208.hdf5
# Epoch 12/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6444 - accuracy: 0.6560 - val_loss: 0.6327 - val_accuracy: 0.6508
#
# Epoch 00012: val_loss did not improve from 0.60031
# Epoch 13/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6430 - accuracy: 0.6527 - val_loss: 0.5973 - val_accuracy: 0.6983
#
# Epoch 00013: val_loss improved from 0.60031 to 0.59728, saving model to ./model_titanic/13-0.6527.hdf5
# Epoch 14/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6414 - accuracy: 0.6644 - val_loss: 0.5869 - val_accuracy: 0.7119
#
# Epoch 00014: val_loss improved from 0.59728 to 0.58687, saving model to ./model_titanic/14-0.6644.hdf5
# Epoch 15/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6427 - accuracy: 0.6711 - val_loss: 0.5871 - val_accuracy: 0.7085
#
# Epoch 00015: val_loss did not improve from 0.58687
# Epoch 16/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6397 - accuracy: 0.6661 - val_loss: 0.5849 - val_accuracy: 0.7051
#
# Epoch 00016: val_loss improved from 0.58687 to 0.58495, saving model to ./model_titanic/16-0.6661.hdf5
# Epoch 17/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6338 - accuracy: 0.6795 - val_loss: 0.5898 - val_accuracy: 0.7119
#
# Epoch 00017: val_loss did not improve from 0.58495
# Epoch 18/2000
# 60/60 [==============================] - 1s 12ms/step - loss: 0.6344 - accuracy: 0.6594 - val_loss: 0.5856 - val_accuracy: 0.7153
#
# Epoch 00018: val_loss did not improve from 0.58495
# Epoch 19/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6356 - accuracy: 0.6594 - val_loss: 0.5859 - val_accuracy: 0.7119
#
# Epoch 00019: val_loss did not improve from 0.58495
# Epoch 20/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6318 - accuracy: 0.6896 - val_loss: 0.5875 - val_accuracy: 0.7220
#
# Epoch 00020: val_loss did not improve from 0.58495
# Epoch 21/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6369 - accuracy: 0.6611 - val_loss: 0.6391 - val_accuracy: 0.6475
#
# Epoch 00021: val_loss did not improve from 0.58495
# Epoch 22/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6345 - accuracy: 0.6544 - val_loss: 0.5794 - val_accuracy: 0.7288
#
# Epoch 00022: val_loss improved from 0.58495 to 0.57937, saving model to ./model_titanic/22-0.6544.hdf5
# Epoch 23/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6518 - accuracy: 0.6560 - val_loss: 0.6043 - val_accuracy: 0.6814
#
# Epoch 00023: val_loss did not improve from 0.57937
# Epoch 24/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6331 - accuracy: 0.6711 - val_loss: 0.5795 - val_accuracy: 0.6915
#
# Epoch 00024: val_loss did not improve from 0.57937
# Epoch 25/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6334 - accuracy: 0.6711 - val_loss: 0.6046 - val_accuracy: 0.6847
#
# Epoch 00025: val_loss did not improve from 0.57937
# Epoch 26/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6264 - accuracy: 0.6661 - val_loss: 0.6828 - val_accuracy: 0.6847
#
# Epoch 00026: val_loss did not improve from 0.57937
# Epoch 27/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6170 - accuracy: 0.6862 - val_loss: 0.5678 - val_accuracy: 0.7085
#
# Epoch 00027: val_loss improved from 0.57937 to 0.56780, saving model to ./model_titanic/27-0.6862.hdf5
# Epoch 28/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6281 - accuracy: 0.6762 - val_loss: 0.6008 - val_accuracy: 0.7153
#
# Epoch 00028: val_loss did not improve from 0.56780
# Epoch 29/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6326 - accuracy: 0.6779 - val_loss: 0.6207 - val_accuracy: 0.6780
#
# Epoch 00029: val_loss did not improve from 0.56780
# Epoch 30/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6291 - accuracy: 0.6745 - val_loss: 0.5783 - val_accuracy: 0.7051
#
# Epoch 00030: val_loss did not improve from 0.56780
# Epoch 31/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6304 - accuracy: 0.6695 - val_loss: 0.5955 - val_accuracy: 0.6915
#
# Epoch 00031: val_loss did not improve from 0.56780
# Epoch 32/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6236 - accuracy: 0.6829 - val_loss: 0.8172 - val_accuracy: 0.4678
#
# Epoch 00032: val_loss did not improve from 0.56780
# Epoch 33/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6342 - accuracy: 0.6560 - val_loss: 0.5988 - val_accuracy: 0.7356
#
# Epoch 00033: val_loss did not improve from 0.56780
# Epoch 34/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6190 - accuracy: 0.6745 - val_loss: 0.6083 - val_accuracy: 0.7119
#
# Epoch 00034: val_loss did not improve from 0.56780
# Epoch 35/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6094 - accuracy: 0.6862 - val_loss: 0.5682 - val_accuracy: 0.7051
#
# Epoch 00035: val_loss did not improve from 0.56780
# Epoch 36/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6068 - accuracy: 0.6913 - val_loss: 0.5925 - val_accuracy: 0.7017
#
# Epoch 00036: val_loss did not improve from 0.56780
# Epoch 37/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6092 - accuracy: 0.6795 - val_loss: 0.7248 - val_accuracy: 0.5322
#
# Epoch 00037: val_loss did not improve from 0.56780
# Epoch 38/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6106 - accuracy: 0.6946 - val_loss: 0.6147 - val_accuracy: 0.7186
#
# Epoch 00038: val_loss did not improve from 0.56780
# Epoch 39/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6183 - accuracy: 0.6795 - val_loss: 0.6004 - val_accuracy: 0.7153
#
# Epoch 00039: val_loss did not improve from 0.56780
# Epoch 40/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6193 - accuracy: 0.6745 - val_loss: 0.6766 - val_accuracy: 0.6339
#
# Epoch 00040: val_loss did not improve from 0.56780
# Epoch 41/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6130 - accuracy: 0.6795 - val_loss: 0.6024 - val_accuracy: 0.7186
#
# Epoch 00041: val_loss did not improve from 0.56780
# Epoch 42/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6060 - accuracy: 0.6862 - val_loss: 0.6364 - val_accuracy: 0.6881
#
# Epoch 00042: val_loss did not improve from 0.56780
# Epoch 43/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6210 - accuracy: 0.6795 - val_loss: 0.5854 - val_accuracy: 0.7186
#
# Epoch 00043: val_loss did not improve from 0.56780
# Epoch 44/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6009 - accuracy: 0.6879 - val_loss: 0.6304 - val_accuracy: 0.7017
#
# Epoch 00044: val_loss did not improve from 0.56780
# Epoch 45/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6119 - accuracy: 0.6963 - val_loss: 0.5658 - val_accuracy: 0.7254
#
# Epoch 00045: val_loss improved from 0.56780 to 0.56582, saving model to ./model_titanic/45-0.6963.hdf5
# Epoch 46/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6103 - accuracy: 0.6896 - val_loss: 0.5720 - val_accuracy: 0.7153
#
# Epoch 00046: val_loss did not improve from 0.56582
# Epoch 47/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5999 - accuracy: 0.7013 - val_loss: 0.5747 - val_accuracy: 0.7085
#
# Epoch 00047: val_loss did not improve from 0.56582
# Epoch 48/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6046 - accuracy: 0.6879 - val_loss: 0.7305 - val_accuracy: 0.5797
#
# Epoch 00048: val_loss did not improve from 0.56582
# Epoch 49/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6157 - accuracy: 0.6779 - val_loss: 0.5775 - val_accuracy: 0.7220
#
# Epoch 00049: val_loss did not improve from 0.56582
# Epoch 50/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6133 - accuracy: 0.6946 - val_loss: 0.6775 - val_accuracy: 0.6847
#
# Epoch 00050: val_loss did not improve from 0.56582
# Epoch 51/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5991 - accuracy: 0.6980 - val_loss: 0.6471 - val_accuracy: 0.6949
#
# Epoch 00051: val_loss did not improve from 0.56582
# Epoch 52/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6095 - accuracy: 0.6896 - val_loss: 0.5950 - val_accuracy: 0.6780
#
# Epoch 00052: val_loss did not improve from 0.56582
# Epoch 53/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6082 - accuracy: 0.6963 - val_loss: 0.5726 - val_accuracy: 0.6949
#
# Epoch 00053: val_loss did not improve from 0.56582
# Epoch 54/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6020 - accuracy: 0.6896 - val_loss: 0.5713 - val_accuracy: 0.7085
#
# Epoch 00054: val_loss did not improve from 0.56582
# Epoch 55/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6108 - accuracy: 0.6779 - val_loss: 0.5753 - val_accuracy: 0.7119
#
# Epoch 00055: val_loss did not improve from 0.56582
# Epoch 56/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5996 - accuracy: 0.6946 - val_loss: 0.5867 - val_accuracy: 0.7186
#
# Epoch 00056: val_loss did not improve from 0.56582
# Epoch 57/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5960 - accuracy: 0.6896 - val_loss: 0.5850 - val_accuracy: 0.7051
#
# Epoch 00057: val_loss did not improve from 0.56582
# Epoch 58/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5871 - accuracy: 0.6980 - val_loss: 0.6528 - val_accuracy: 0.6780
#
# Epoch 00058: val_loss did not improve from 0.56582
# Epoch 59/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5997 - accuracy: 0.6980 - val_loss: 0.6271 - val_accuracy: 0.6847
#
# Epoch 00059: val_loss did not improve from 0.56582
# Epoch 60/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6043 - accuracy: 0.6879 - val_loss: 0.6275 - val_accuracy: 0.6915
#
# Epoch 00060: val_loss did not improve from 0.56582
# Epoch 61/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5902 - accuracy: 0.7081 - val_loss: 0.5696 - val_accuracy: 0.7119
#
# Epoch 00061: val_loss did not improve from 0.56582
# Epoch 62/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5858 - accuracy: 0.6980 - val_loss: 0.5839 - val_accuracy: 0.6983
#
# Epoch 00062: val_loss did not improve from 0.56582
# Epoch 63/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5951 - accuracy: 0.6930 - val_loss: 0.5812 - val_accuracy: 0.7051
#
# Epoch 00063: val_loss did not improve from 0.56582
# Epoch 64/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5923 - accuracy: 0.6913 - val_loss: 0.6027 - val_accuracy: 0.6915
#
# Epoch 00064: val_loss did not improve from 0.56582
# Epoch 65/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5921 - accuracy: 0.6946 - val_loss: 0.5676 - val_accuracy: 0.7186
#
# Epoch 00065: val_loss did not improve from 0.56582
# Epoch 66/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5958 - accuracy: 0.7064 - val_loss: 0.6490 - val_accuracy: 0.6780
#
# Epoch 00066: val_loss did not improve from 0.56582
# Epoch 67/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5933 - accuracy: 0.7114 - val_loss: 0.6968 - val_accuracy: 0.6814
#
# Epoch 00067: val_loss did not improve from 0.56582
# Epoch 68/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5949 - accuracy: 0.6946 - val_loss: 0.5948 - val_accuracy: 0.7254
#
# Epoch 00068: val_loss did not improve from 0.56582
# Epoch 69/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5890 - accuracy: 0.6946 - val_loss: 0.6709 - val_accuracy: 0.6780
#
# Epoch 00069: val_loss did not improve from 0.56582
# Epoch 70/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5855 - accuracy: 0.7030 - val_loss: 0.6843 - val_accuracy: 0.7051
#
# Epoch 00070: val_loss did not improve from 0.56582
# Epoch 71/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6146 - accuracy: 0.6963 - val_loss: 0.6343 - val_accuracy: 0.6915
#
# Epoch 00071: val_loss did not improve from 0.56582
# Epoch 72/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6091 - accuracy: 0.6829 - val_loss: 0.6034 - val_accuracy: 0.6915
#
# Epoch 00072: val_loss did not improve from 0.56582
# Epoch 73/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6099 - accuracy: 0.6930 - val_loss: 0.6070 - val_accuracy: 0.7186
#
# Epoch 00073: val_loss did not improve from 0.56582
# Epoch 74/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6191 - accuracy: 0.6829 - val_loss: 0.5830 - val_accuracy: 0.7119
#
# Epoch 00074: val_loss did not improve from 0.56582
# Epoch 75/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5908 - accuracy: 0.7030 - val_loss: 0.6025 - val_accuracy: 0.7051
#
# Epoch 00075: val_loss did not improve from 0.56582
# Epoch 76/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5876 - accuracy: 0.7013 - val_loss: 0.6232 - val_accuracy: 0.6881
#
# Epoch 00076: val_loss did not improve from 0.56582
# Epoch 77/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6171 - accuracy: 0.6762 - val_loss: 0.5848 - val_accuracy: 0.7254
#
# Epoch 00077: val_loss did not improve from 0.56582
# Epoch 78/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5902 - accuracy: 0.7097 - val_loss: 0.6002 - val_accuracy: 0.6949
#
# Epoch 00078: val_loss did not improve from 0.56582
# Epoch 79/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.6131 - accuracy: 0.6896 - val_loss: 0.5811 - val_accuracy: 0.6983
#
# Epoch 00079: val_loss did not improve from 0.56582
# Epoch 80/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5846 - accuracy: 0.7047 - val_loss: 0.8636 - val_accuracy: 0.5322
#
# Epoch 00080: val_loss did not improve from 0.56582
# Epoch 81/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5834 - accuracy: 0.7114 - val_loss: 0.5710 - val_accuracy: 0.7220
# Epoch 00081: val_loss did not improve from 0.56582
# Epoch 82/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5811 - accuracy: 0.6997 - val_loss: 0.5888 - val_accuracy: 0.7085
#
# Epoch 00082: val_loss did not improve from 0.56582
# Epoch 83/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5882 - accuracy: 0.6930 - val_loss: 0.5695 - val_accuracy: 0.7051
#
# Epoch 00083: val_loss did not improve from 0.56582
# Epoch 84/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5833 - accuracy: 0.7114 - val_loss: 0.7276 - val_accuracy: 0.6441
#
# Epoch 00084: val_loss did not improve from 0.56582
# Epoch 85/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5850 - accuracy: 0.7047 - val_loss: 0.5976 - val_accuracy: 0.6915
#
# Epoch 00085: val_loss did not improve from 0.56582
# Epoch 86/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5774 - accuracy: 0.7081 - val_loss: 0.7131 - val_accuracy: 0.6203
#
# Epoch 00086: val_loss did not improve from 0.56582
# Epoch 87/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5712 - accuracy: 0.7097 - val_loss: 0.5937 - val_accuracy: 0.7220
#
# Epoch 00087: val_loss did not improve from 0.56582
# Epoch 88/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5850 - accuracy: 0.7047 - val_loss: 0.6510 - val_accuracy: 0.7017
#
# Epoch 00088: val_loss did not improve from 0.56582
# Epoch 89/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5727 - accuracy: 0.7164 - val_loss: 0.5722 - val_accuracy: 0.7153
#
# Epoch 00089: val_loss did not improve from 0.56582
# Epoch 90/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5659 - accuracy: 0.7164 - val_loss: 0.6520 - val_accuracy: 0.7119
#
# Epoch 00090: val_loss did not improve from 0.56582
# Epoch 91/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5623 - accuracy: 0.7164 - val_loss: 0.5939 - val_accuracy: 0.7017
#
# Epoch 00091: val_loss did not improve from 0.56582
# Epoch 92/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5652 - accuracy: 0.7114 - val_loss: 0.8365 - val_accuracy: 0.5695
#
# Epoch 00092: val_loss did not improve from 0.56582
# Epoch 93/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5740 - accuracy: 0.7114 - val_loss: 0.5721 - val_accuracy: 0.7119
#
# Epoch 00093: val_loss did not improve from 0.56582
# Epoch 94/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5664 - accuracy: 0.7081 - val_loss: 0.9263 - val_accuracy: 0.4847
#
# Epoch 00094: val_loss did not improve from 0.56582
# Epoch 95/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5813 - accuracy: 0.7097 - val_loss: 0.6038 - val_accuracy: 0.6847
#
# Epoch 00095: val_loss did not improve from 0.56582
# Epoch 96/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5577 - accuracy: 0.7315 - val_loss: 0.7262 - val_accuracy: 0.6949
#
# Epoch 00096: val_loss did not improve from 0.56582
# Epoch 97/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5713 - accuracy: 0.7064 - val_loss: 0.6382 - val_accuracy: 0.6983
#
# Epoch 00097: val_loss did not improve from 0.56582
# Epoch 98/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5772 - accuracy: 0.7181 - val_loss: 0.6365 - val_accuracy: 0.6915
#
# Epoch 00098: val_loss did not improve from 0.56582
# Epoch 99/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5737 - accuracy: 0.7047 - val_loss: 0.5872 - val_accuracy: 0.7153
#
# Epoch 00099: val_loss did not improve from 0.56582
# Epoch 100/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5665 - accuracy: 0.7232 - val_loss: 0.6080 - val_accuracy: 0.6814
#
# Epoch 00100: val_loss did not improve from 0.56582
# Epoch 101/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5634 - accuracy: 0.7232 - val_loss: 0.6416 - val_accuracy: 0.6915
#
# Epoch 00101: val_loss did not improve from 0.56582
# Epoch 102/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5583 - accuracy: 0.7164 - val_loss: 0.7787 - val_accuracy: 0.6102
#
# Epoch 00102: val_loss did not improve from 0.56582
# Epoch 103/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5544 - accuracy: 0.7282 - val_loss: 0.6260 - val_accuracy: 0.6949
#
# Epoch 00103: val_loss did not improve from 0.56582
# Epoch 104/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5524 - accuracy: 0.7248 - val_loss: 0.6580 - val_accuracy: 0.7051
#
# Epoch 00104: val_loss did not improve from 0.56582
# Epoch 105/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5496 - accuracy: 0.7416 - val_loss: 0.6691 - val_accuracy: 0.6780
#
# Epoch 00105: val_loss did not improve from 0.56582
# Epoch 106/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5461 - accuracy: 0.7399 - val_loss: 0.6600 - val_accuracy: 0.6949
#
# Epoch 00106: val_loss did not improve from 0.56582
# Epoch 107/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5638 - accuracy: 0.7282 - val_loss: 0.7420 - val_accuracy: 0.6610
#
# Epoch 00107: val_loss did not improve from 0.56582
# Epoch 108/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5891 - accuracy: 0.6963 - val_loss: 0.6727 - val_accuracy: 0.6814
#
# Epoch 00108: val_loss did not improve from 0.56582
# Epoch 109/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5584 - accuracy: 0.7383 - val_loss: 0.6371 - val_accuracy: 0.6983
#
# Epoch 00109: val_loss did not improve from 0.56582
# Epoch 110/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5594 - accuracy: 0.7332 - val_loss: 0.6027 - val_accuracy: 0.7220
#
# Epoch 00110: val_loss did not improve from 0.56582
# Epoch 111/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5437 - accuracy: 0.7383 - val_loss: 0.6079 - val_accuracy: 0.7186
#
# Epoch 00111: val_loss did not improve from 0.56582
# Epoch 112/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5420 - accuracy: 0.7315 - val_loss: 0.6177 - val_accuracy: 0.7220
#
# Epoch 00112: val_loss did not improve from 0.56582
# Epoch 113/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5461 - accuracy: 0.7198 - val_loss: 0.6302 - val_accuracy: 0.7186
#
# Epoch 00113: val_loss did not improve from 0.56582
# Epoch 114/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5299 - accuracy: 0.7399 - val_loss: 0.7056 - val_accuracy: 0.6949
#
# Epoch 00114: val_loss did not improve from 0.56582
# Epoch 115/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5660 - accuracy: 0.7349 - val_loss: 0.8435 - val_accuracy: 0.6203
#
# Epoch 00115: val_loss did not improve from 0.56582
# Epoch 116/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5549 - accuracy: 0.7299 - val_loss: 0.5771 - val_accuracy: 0.7254
#
# Epoch 00116: val_loss did not improve from 0.56582
# Epoch 117/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5440 - accuracy: 0.7315 - val_loss: 0.5818 - val_accuracy: 0.7119
#
# Epoch 00117: val_loss did not improve from 0.56582
# Epoch 118/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5529 - accuracy: 0.7248 - val_loss: 0.7005 - val_accuracy: 0.7085
#
# Epoch 00118: val_loss did not improve from 0.56582
# Epoch 119/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5547 - accuracy: 0.7265 - val_loss: 0.6409 - val_accuracy: 0.7051
#
# Epoch 00119: val_loss did not improve from 0.56582
# Epoch 120/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5595 - accuracy: 0.7265 - val_loss: 0.5744 - val_accuracy: 0.7153
#
# Epoch 00120: val_loss did not improve from 0.56582
# Epoch 121/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5492 - accuracy: 0.7299 - val_loss: 0.6138 - val_accuracy: 0.7220
#
# Epoch 00121: val_loss did not improve from 0.56582
# Epoch 122/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5533 - accuracy: 0.7315 - val_loss: 0.6270 - val_accuracy: 0.6881
#
# Epoch 00122: val_loss did not improve from 0.56582
# Epoch 123/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5580 - accuracy: 0.7114 - val_loss: 0.5725 - val_accuracy: 0.7254
#
# Epoch 00123: val_loss did not improve from 0.56582
# Epoch 124/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5464 - accuracy: 0.7383 - val_loss: 0.5832 - val_accuracy: 0.7254
#
# Epoch 00124: val_loss did not improve from 0.56582
# Epoch 125/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5347 - accuracy: 0.7383 - val_loss: 0.7328 - val_accuracy: 0.6847
#
# Epoch 00125: val_loss did not improve from 0.56582
# Epoch 126/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5539 - accuracy: 0.7433 - val_loss: 0.7917 - val_accuracy: 0.5525
#
# Epoch 00126: val_loss did not improve from 0.56582
# Epoch 127/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5349 - accuracy: 0.7550 - val_loss: 0.6419 - val_accuracy: 0.6949
#
# Epoch 00127: val_loss did not improve from 0.56582
# Epoch 128/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5333 - accuracy: 0.7517 - val_loss: 0.6139 - val_accuracy: 0.7220
#
# Epoch 00128: val_loss did not improve from 0.56582
# Epoch 129/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5530 - accuracy: 0.7299 - val_loss: 0.6021 - val_accuracy: 0.7220
#
# Epoch 00129: val_loss did not improve from 0.56582
# Epoch 130/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5151 - accuracy: 0.7466 - val_loss: 0.6545 - val_accuracy: 0.6983
#
# Epoch 00130: val_loss did not improve from 0.56582
# Epoch 131/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5249 - accuracy: 0.7466 - val_loss: 0.5905 - val_accuracy: 0.7119
#
# Epoch 00131: val_loss did not improve from 0.56582
# Epoch 132/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5263 - accuracy: 0.7433 - val_loss: 0.7678 - val_accuracy: 0.7085
#
# Epoch 00132: val_loss did not improve from 0.56582
# Epoch 133/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5217 - accuracy: 0.7416 - val_loss: 0.6222 - val_accuracy: 0.6983
#
# Epoch 00133: val_loss did not improve from 0.56582
# Epoch 134/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5107 - accuracy: 0.7550 - val_loss: 0.6373 - val_accuracy: 0.7186
#
# Epoch 00134: val_loss did not improve from 0.56582
# Epoch 135/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5070 - accuracy: 0.7617 - val_loss: 0.5686 - val_accuracy: 0.7288
#
# Epoch 00135: val_loss did not improve from 0.56582
# Epoch 136/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4988 - accuracy: 0.7617 - val_loss: 0.6392 - val_accuracy: 0.6949
#
# Epoch 00136: val_loss did not improve from 0.56582
# Epoch 137/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4985 - accuracy: 0.7668 - val_loss: 0.7925 - val_accuracy: 0.6203
#
# Epoch 00137: val_loss did not improve from 0.56582
# Epoch 138/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5136 - accuracy: 0.7416 - val_loss: 0.6574 - val_accuracy: 0.6881
#
# Epoch 00138: val_loss did not improve from 0.56582
# Epoch 139/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5119 - accuracy: 0.7550 - val_loss: 0.5969 - val_accuracy: 0.7220
#
# Epoch 00139: val_loss did not improve from 0.56582
# Epoch 140/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5156 - accuracy: 0.7601 - val_loss: 0.5888 - val_accuracy: 0.7254
#
# Epoch 00140: val_loss did not improve from 0.56582
# Epoch 141/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5413 - accuracy: 0.7366 - val_loss: 0.5747 - val_accuracy: 0.7322
#
# Epoch 00141: val_loss did not improve from 0.56582
# Epoch 142/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5144 - accuracy: 0.7433 - val_loss: 0.5829 - val_accuracy: 0.7085
#
# Epoch 00142: val_loss did not improve from 0.56582
# Epoch 143/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4894 - accuracy: 0.7668 - val_loss: 0.6332 - val_accuracy: 0.7017
#
# Epoch 00143: val_loss did not improve from 0.56582
# Epoch 144/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4914 - accuracy: 0.7768 - val_loss: 0.6031 - val_accuracy: 0.7186
#
# Epoch 00144: val_loss did not improve from 0.56582
# Epoch 145/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.5110 - accuracy: 0.7651 - val_loss: 0.5864 - val_accuracy: 0.7254
#
# Epoch 00145: val_loss did not improve from 0.56582
# Epoch 146/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4989 - accuracy: 0.7601 - val_loss: 0.6066 - val_accuracy: 0.7017
#
# Epoch 00146: val_loss did not improve from 0.56582
# Epoch 147/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4878 - accuracy: 0.7668 - val_loss: 0.6330 - val_accuracy: 0.6949
#
# Epoch 00147: val_loss did not improve from 0.56582
# Epoch 148/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4950 - accuracy: 0.7617 - val_loss: 0.6519 - val_accuracy: 0.6746
#
# Epoch 00148: val_loss did not improve from 0.56582
# Epoch 149/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4936 - accuracy: 0.7651 - val_loss: 0.5994 - val_accuracy: 0.7153
#
# Epoch 00149: val_loss did not improve from 0.56582
# Epoch 150/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4737 - accuracy: 0.7953 - val_loss: 0.6956 - val_accuracy: 0.7186
#
# Epoch 00150: val_loss did not improve from 0.56582
# Epoch 151/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4919 - accuracy: 0.7752 - val_loss: 0.6374 - val_accuracy: 0.7186
#
# Epoch 00151: val_loss did not improve from 0.56582
# Epoch 152/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4869 - accuracy: 0.7752 - val_loss: 0.6067 - val_accuracy: 0.7119
#
# Epoch 00152: val_loss did not improve from 0.56582
# Epoch 153/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4684 - accuracy: 0.7970 - val_loss: 0.6172 - val_accuracy: 0.7153
#
# Epoch 00153: val_loss did not improve from 0.56582
# Epoch 154/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4560 - accuracy: 0.7970 - val_loss: 0.6126 - val_accuracy: 0.7017
#
# Epoch 00154: val_loss did not improve from 0.56582
# Epoch 155/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4572 - accuracy: 0.7903 - val_loss: 0.6265 - val_accuracy: 0.7119
#
# Epoch 00155: val_loss did not improve from 0.56582
# Epoch 156/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4801 - accuracy: 0.7718 - val_loss: 0.7385 - val_accuracy: 0.6915
#
# Epoch 00156: val_loss did not improve from 0.56582
# Epoch 157/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4758 - accuracy: 0.7768 - val_loss: 0.6132 - val_accuracy: 0.6881
#
# Epoch 00157: val_loss did not improve from 0.56582
# Epoch 158/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4610 - accuracy: 0.7886 - val_loss: 0.5852 - val_accuracy: 0.7254
#
# Epoch 00158: val_loss did not improve from 0.56582
# Epoch 159/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4817 - accuracy: 0.7735 - val_loss: 0.5703 - val_accuracy: 0.7458
#
# Epoch 00159: val_loss did not improve from 0.56582
# Epoch 160/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4774 - accuracy: 0.7685 - val_loss: 0.5987 - val_accuracy: 0.7153
#
# Epoch 00160: val_loss did not improve from 0.56582
# Epoch 161/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4456 - accuracy: 0.8104 - val_loss: 0.6676 - val_accuracy: 0.6847
#
# Epoch 00161: val_loss did not improve from 0.56582
# Epoch 162/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4500 - accuracy: 0.7987 - val_loss: 0.6690 - val_accuracy: 0.7186
#
# Epoch 00162: val_loss did not improve from 0.56582
# Epoch 163/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4600 - accuracy: 0.7903 - val_loss: 0.6912 - val_accuracy: 0.7017
#
# Epoch 00163: val_loss did not improve from 0.56582
# Epoch 164/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4563 - accuracy: 0.7869 - val_loss: 0.6922 - val_accuracy: 0.7017
# Epoch 00164: val_loss did not improve from 0.56582
# Epoch 165/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4527 - accuracy: 0.7953 - val_loss: 0.7388 - val_accuracy: 0.7390
#
# Epoch 00165: val_loss did not improve from 0.56582
# Epoch 166/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4637 - accuracy: 0.8054 - val_loss: 0.5980 - val_accuracy: 0.7017
#
# Epoch 00166: val_loss did not improve from 0.56582
# Epoch 167/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4246 - accuracy: 0.8188 - val_loss: 0.6289 - val_accuracy: 0.7254
#
# Epoch 00167: val_loss did not improve from 0.56582
# Epoch 168/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4723 - accuracy: 0.7987 - val_loss: 0.6833 - val_accuracy: 0.7390
#
# Epoch 00168: val_loss did not improve from 0.56582
# Epoch 169/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4243 - accuracy: 0.8138 - val_loss: 0.5990 - val_accuracy: 0.7017
#
# Epoch 00169: val_loss did not improve from 0.56582
# Epoch 170/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4543 - accuracy: 0.8070 - val_loss: 0.5806 - val_accuracy: 0.7017
#
# Epoch 00170: val_loss did not improve from 0.56582
# Epoch 171/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4295 - accuracy: 0.8121 - val_loss: 0.5891 - val_accuracy: 0.7051
#
# Epoch 00171: val_loss did not improve from 0.56582
# Epoch 172/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4365 - accuracy: 0.8037 - val_loss: 0.8725 - val_accuracy: 0.5763
#
# Epoch 00172: val_loss did not improve from 0.56582
# Epoch 173/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4458 - accuracy: 0.7903 - val_loss: 0.6070 - val_accuracy: 0.7186
#
# Epoch 00173: val_loss did not improve from 0.56582
# Epoch 174/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4442 - accuracy: 0.8087 - val_loss: 0.6592 - val_accuracy: 0.7254
#
# Epoch 00174: val_loss did not improve from 0.56582
# Epoch 175/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4316 - accuracy: 0.8138 - val_loss: 0.6434 - val_accuracy: 0.7356
#
# Epoch 00175: val_loss did not improve from 0.56582
# Epoch 176/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4187 - accuracy: 0.8221 - val_loss: 0.7994 - val_accuracy: 0.7153
#
# Epoch 00176: val_loss did not improve from 0.56582
# Epoch 177/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4441 - accuracy: 0.8104 - val_loss: 0.6449 - val_accuracy: 0.7220
#
# Epoch 00177: val_loss did not improve from 0.56582
# Epoch 178/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4479 - accuracy: 0.8104 - val_loss: 0.6024 - val_accuracy: 0.7186
#
# Epoch 00178: val_loss did not improve from 0.56582
# Epoch 179/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4370 - accuracy: 0.8037 - val_loss: 0.5842 - val_accuracy: 0.7254
#
# Epoch 00179: val_loss did not improve from 0.56582
# Epoch 180/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4347 - accuracy: 0.8037 - val_loss: 0.7189 - val_accuracy: 0.6983
#
# Epoch 00180: val_loss did not improve from 0.56582
# Epoch 181/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4799 - accuracy: 0.7735 - val_loss: 0.5770 - val_accuracy: 0.7119
#
# Epoch 00181: val_loss did not improve from 0.56582
# Epoch 182/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4238 - accuracy: 0.8188 - val_loss: 0.5473 - val_accuracy: 0.7356
#
# Epoch 00182: val_loss improved from 0.56582 to 0.54728, saving model to ./model_titanic/182-0.8188.hdf5
# Epoch 183/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4225 - accuracy: 0.8121 - val_loss: 0.6712 - val_accuracy: 0.7085
#
# Epoch 00183: val_loss did not improve from 0.54728
# Epoch 184/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4021 - accuracy: 0.8356 - val_loss: 0.6553 - val_accuracy: 0.7424
#
# Epoch 00184: val_loss did not improve from 0.54728
# Epoch 185/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4218 - accuracy: 0.8221 - val_loss: 0.6259 - val_accuracy: 0.7390
#
# Epoch 00185: val_loss did not improve from 0.54728
# Epoch 186/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4341 - accuracy: 0.7936 - val_loss: 0.6558 - val_accuracy: 0.7390
#
# Epoch 00186: val_loss did not improve from 0.54728
# Epoch 187/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4601 - accuracy: 0.7936 - val_loss: 0.6686 - val_accuracy: 0.7085
#
# Epoch 00187: val_loss did not improve from 0.54728
# Epoch 188/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4085 - accuracy: 0.8188 - val_loss: 0.8393 - val_accuracy: 0.6169
#
# Epoch 00188: val_loss did not improve from 0.54728
# Epoch 189/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4212 - accuracy: 0.8205 - val_loss: 0.6606 - val_accuracy: 0.7288
#
# Epoch 00189: val_loss did not improve from 0.54728
# Epoch 190/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4141 - accuracy: 0.8171 - val_loss: 0.5752 - val_accuracy: 0.7424
#
# Epoch 00190: val_loss did not improve from 0.54728
# Epoch 191/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4030 - accuracy: 0.8289 - val_loss: 0.7513 - val_accuracy: 0.6644
#
# Epoch 00191: val_loss did not improve from 0.54728
# Epoch 192/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4328 - accuracy: 0.8121 - val_loss: 0.6345 - val_accuracy: 0.7356
#
# Epoch 00192: val_loss did not improve from 0.54728
# Epoch 193/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4043 - accuracy: 0.8322 - val_loss: 0.6286 - val_accuracy: 0.7424
#
# Epoch 00193: val_loss did not improve from 0.54728
# Epoch 194/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4285 - accuracy: 0.8205 - val_loss: 0.5633 - val_accuracy: 0.7322
#
# Epoch 00194: val_loss did not improve from 0.54728
# Epoch 195/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4175 - accuracy: 0.8154 - val_loss: 1.0624 - val_accuracy: 0.5322
#
# Epoch 00195: val_loss did not improve from 0.54728
# Epoch 196/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4257 - accuracy: 0.8205 - val_loss: 0.6241 - val_accuracy: 0.7288
#
# Epoch 00196: val_loss did not improve from 0.54728
# Epoch 197/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4259 - accuracy: 0.8037 - val_loss: 0.6782 - val_accuracy: 0.6814
#
# Epoch 00197: val_loss did not improve from 0.54728
# Epoch 198/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4184 - accuracy: 0.8154 - val_loss: 0.5565 - val_accuracy: 0.7254
#
# Epoch 00198: val_loss did not improve from 0.54728
# Epoch 199/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3887 - accuracy: 0.8423 - val_loss: 0.5730 - val_accuracy: 0.7220
#
# Epoch 00199: val_loss did not improve from 0.54728
# Epoch 200/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3793 - accuracy: 0.8305 - val_loss: 0.7080 - val_accuracy: 0.7119
#
# Epoch 00200: val_loss did not improve from 0.54728
# Epoch 201/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4159 - accuracy: 0.8205 - val_loss: 0.5415 - val_accuracy: 0.7390
#
# Epoch 00201: val_loss improved from 0.54728 to 0.54149, saving model to ./model_titanic/201-0.8205.hdf5
# Epoch 202/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3853 - accuracy: 0.8221 - val_loss: 0.5647 - val_accuracy: 0.7356
#
# Epoch 00202: val_loss did not improve from 0.54149
# Epoch 203/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4623 - accuracy: 0.7936 - val_loss: 0.5457 - val_accuracy: 0.7186
#
# Epoch 00203: val_loss did not improve from 0.54149
# Epoch 204/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4321 - accuracy: 0.8171 - val_loss: 0.5764 - val_accuracy: 0.7525
#
# Epoch 00204: val_loss did not improve from 0.54149
# Epoch 205/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4118 - accuracy: 0.8171 - val_loss: 0.5989 - val_accuracy: 0.7220
#
# Epoch 00205: val_loss did not improve from 0.54149
# Epoch 206/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3879 - accuracy: 0.8356 - val_loss: 0.6287 - val_accuracy: 0.7254
#
# Epoch 00206: val_loss did not improve from 0.54149
# Epoch 207/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3781 - accuracy: 0.8440 - val_loss: 0.6874 - val_accuracy: 0.7390
#
# Epoch 00207: val_loss did not improve from 0.54149
# Epoch 208/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3767 - accuracy: 0.8389 - val_loss: 0.8797 - val_accuracy: 0.6203
#
# Epoch 00208: val_loss did not improve from 0.54149
# Epoch 209/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4313 - accuracy: 0.8087 - val_loss: 0.8784 - val_accuracy: 0.6271
#
# Epoch 00209: val_loss did not improve from 0.54149
# Epoch 210/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4187 - accuracy: 0.8171 - val_loss: 0.6464 - val_accuracy: 0.7322
#
# Epoch 00210: val_loss did not improve from 0.54149
# Epoch 211/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3634 - accuracy: 0.8473 - val_loss: 0.5997 - val_accuracy: 0.7153
#
# Epoch 00211: val_loss did not improve from 0.54149
# Epoch 212/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3671 - accuracy: 0.8507 - val_loss: 0.5717 - val_accuracy: 0.7322
#
# Epoch 00212: val_loss did not improve from 0.54149
# Epoch 213/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3717 - accuracy: 0.8322 - val_loss: 0.7324 - val_accuracy: 0.7085
#
# Epoch 00213: val_loss did not improve from 0.54149
# Epoch 214/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4084 - accuracy: 0.8305 - val_loss: 0.7031 - val_accuracy: 0.7492
#
# Epoch 00214: val_loss did not improve from 0.54149
# Epoch 215/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4517 - accuracy: 0.8138 - val_loss: 0.5469 - val_accuracy: 0.7322
#
# Epoch 00215: val_loss did not improve from 0.54149
# Epoch 216/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4235 - accuracy: 0.8188 - val_loss: 0.5841 - val_accuracy: 0.7051
#
# Epoch 00216: val_loss did not improve from 0.54149
# Epoch 217/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3726 - accuracy: 0.8440 - val_loss: 0.5697 - val_accuracy: 0.7390
#
# Epoch 00217: val_loss did not improve from 0.54149
# Epoch 218/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3924 - accuracy: 0.8171 - val_loss: 0.6920 - val_accuracy: 0.6847
#
# Epoch 00218: val_loss did not improve from 0.54149
# Epoch 219/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4005 - accuracy: 0.8322 - val_loss: 0.5845 - val_accuracy: 0.7458
#
# Epoch 00219: val_loss did not improve from 0.54149
# Epoch 220/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4067 - accuracy: 0.8188 - val_loss: 0.6032 - val_accuracy: 0.7220
#
# Epoch 00220: val_loss did not improve from 0.54149
# Epoch 221/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3716 - accuracy: 0.8423 - val_loss: 0.6849 - val_accuracy: 0.7390
#
# Epoch 00221: val_loss did not improve from 0.54149
# Epoch 222/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3611 - accuracy: 0.8423 - val_loss: 1.0259 - val_accuracy: 0.5525
#
# Epoch 00222: val_loss did not improve from 0.54149
# Epoch 223/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3825 - accuracy: 0.8339 - val_loss: 0.6820 - val_accuracy: 0.7492
#
# Epoch 00223: val_loss did not improve from 0.54149
# Epoch 224/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3643 - accuracy: 0.8339 - val_loss: 0.6352 - val_accuracy: 0.7153
#
# Epoch 00224: val_loss did not improve from 0.54149
# Epoch 225/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4000 - accuracy: 0.8255 - val_loss: 0.5699 - val_accuracy: 0.7288
#
# Epoch 00225: val_loss did not improve from 0.54149
# Epoch 226/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4449 - accuracy: 0.8272 - val_loss: 0.6197 - val_accuracy: 0.7492
#
# Epoch 00226: val_loss did not improve from 0.54149
# Epoch 227/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4272 - accuracy: 0.8104 - val_loss: 0.5957 - val_accuracy: 0.7424
#
# Epoch 00227: val_loss did not improve from 0.54149
# Epoch 228/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3831 - accuracy: 0.8339 - val_loss: 0.6235 - val_accuracy: 0.7322
#
# Epoch 00228: val_loss did not improve from 0.54149
# Epoch 229/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3781 - accuracy: 0.8440 - val_loss: 0.7290 - val_accuracy: 0.7085
#
# Epoch 00229: val_loss did not improve from 0.54149
# Epoch 230/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3752 - accuracy: 0.8372 - val_loss: 0.8828 - val_accuracy: 0.6305
#
# Epoch 00230: val_loss did not improve from 0.54149
# Epoch 231/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3571 - accuracy: 0.8423 - val_loss: 0.6038 - val_accuracy: 0.7322
#
# Epoch 00231: val_loss did not improve from 0.54149
# Epoch 232/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3561 - accuracy: 0.8557 - val_loss: 0.6349 - val_accuracy: 0.7492
#
# Epoch 00232: val_loss did not improve from 0.54149
# Epoch 233/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4170 - accuracy: 0.8003 - val_loss: 0.6043 - val_accuracy: 0.7458
#
# Epoch 00233: val_loss did not improve from 0.54149
# Epoch 234/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3645 - accuracy: 0.8507 - val_loss: 0.5949 - val_accuracy: 0.7254
#
# Epoch 00234: val_loss did not improve from 0.54149
# Epoch 235/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3715 - accuracy: 0.8423 - val_loss: 0.6290 - val_accuracy: 0.7559
#
# Epoch 00235: val_loss did not improve from 0.54149
# Epoch 236/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3426 - accuracy: 0.8557 - val_loss: 1.1510 - val_accuracy: 0.6407
#
# Epoch 00236: val_loss did not improve from 0.54149
# Epoch 237/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4552 - accuracy: 0.8121 - val_loss: 0.6917 - val_accuracy: 0.6508
#
# Epoch 00237: val_loss did not improve from 0.54149
# Epoch 238/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4385 - accuracy: 0.8121 - val_loss: 0.9068 - val_accuracy: 0.6678
#
# Epoch 00238: val_loss did not improve from 0.54149
# Epoch 239/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.4083 - accuracy: 0.8322 - val_loss: 0.6284 - val_accuracy: 0.7322
#
# Epoch 00239: val_loss did not improve from 0.54149
# Epoch 240/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3594 - accuracy: 0.8523 - val_loss: 0.7963 - val_accuracy: 0.7254
#
# Epoch 00240: val_loss did not improve from 0.54149
# Epoch 241/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3636 - accuracy: 0.8423 - val_loss: 0.9774 - val_accuracy: 0.6712
#
# ...
#
# Epoch 01163: val_loss did not improve from 0.52451
# Epoch 1164/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.3590 - accuracy: 0.8809 - val_loss: 1.7463 - val_accuracy: 0.6305
#
# Epoch 01164: val_loss did not improve from 0.52451
# Epoch 1165/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.1334 - accuracy: 0.9547 - val_loss: 1.4894 - val_accuracy: 0.6712
#
# Epoch 01165: val_loss did not improve from 0.52451
# Epoch 1166/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.1497 - accuracy: 0.9396 - val_loss: 1.1685 - val_accuracy: 0.7119
#
# Epoch 01166: val_loss did not improve from 0.52451
# Epoch 1167/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.2747 - accuracy: 0.8826 - val_loss: 0.9631 - val_accuracy: 0.7458
#
# Epoch 01167: val_loss did not improve from 0.52451
# Epoch 1168/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.1893 - accuracy: 0.9312 - val_loss: 1.0313 - val_accuracy: 0.5864
#
# Epoch 01168: val_loss did not improve from 0.52451
# Epoch 1169/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0995 - accuracy: 0.9698 - val_loss: 1.2365 - val_accuracy: 0.6847
#
# Epoch 01169: val_loss did not improve from 0.52451
# Epoch 1170/2000
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0622 - accuracy: 0.9815 - val_loss: 1.5147 - val_accuracy: 0.6576
#
# Epoch 01170: val_loss did not improve from 0.52451
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 30)                360
# _________________________________________________________________
# dense_37 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_38 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_39 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_40 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_41 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_42 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_43 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_44 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_45 (Dense)             (None, 2)                 62
# =================================================================
# Total params: 7,862
# Trainable params: 7,862
# Non-trainable params: 0
# _________________________________________________________________
# 데이터 : [9.99964118e-01 3.58640100e-05 1.55789847e-03 9.98442113e-01
#  7.19606221e-01 2.80393839e-01 5.98426819e-01 4.01573241e-01
#  9.75351274e-01 2.46487558e-02 9.76021409e-01 2.39786580e-02
#  9.70172167e-01 2.98278537e-02 5.11166263e-06 9.99994874e-01
#  4.43863235e-02 9.55613673e-01 2.29172812e-07 9.99999762e-01
#  9.99904156e-01 9.58100427e-05 6.93902135e-01 3.06097895e-01
#  1.91032642e-03 9.98089671e-01 5.39559662e-01 4.60440427e-01
#  5.81625327e-02 9.41837430e-01 9.66066072e-09 1.00000000e+00
#  9.99944806e-01 5.51833546e-05 3.31117094e-01 6.68882966e-01
#  9.88336742e-01 1.16632124e-02 9.08090830e-01 9.19091478e-02
#  6.31426461e-04 9.99368608e-01 9.99622762e-01 3.77241784e-04
#  6.02683239e-03 9.93973196e-01 8.09339981e-04 9.99190629e-01
