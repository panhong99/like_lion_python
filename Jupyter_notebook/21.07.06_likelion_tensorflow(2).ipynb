# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.4.1'

# %%
import tensorflow as tf
import numpy as np
from datetime import datetime

data = [[2,81] , [4, 93] , [6, 91] , [8 , 97]]
x_train = [x_row[0] for x_row in data]
y_train = [y_row[1] for y_row in data]
w = tf.Variable(tf.random.uniform([1] , 0 , 10 , dtype = tf.float64 , seed = 0))
b = tf.Variable(tf.random.uniform([1] , 0 , 100 , dtype = tf.float64 , seed = 0))

def hypothesis(w , b):
    return x_train * w + b

@tf.function
def costFunc():
    return tf.sqrt(tf.reduce_mean(tf.square(hypothesis(w, b) - y_train)))

def hello(w , b):
    return tf.sqrt(tf.reduce_mean(tf.square(hypothesis(w,b) - y_train)))

stamp = datetime.now().strftime("%Y%m%d-%H%M%S")
logdir = "logs/mylogs/%s" % stamp
writer = tf.summary.create_file_writer(logdir)
tf.summary.trace_on(graph = True , profiler = True)
costFunc()

with writer.as_default():
    tf.summary.trace_export(name = "graph_t1" , step = 0 , profiler_outdir = logdir)
    
    
opt = tf.keras.optimizers.SGD(learning_rate = 0.1)

for i in range(2000):
    opt.minimize(costFunc , var_list = [w, b])
    if i % 100 == 0:
        print(i , f"{hello(w , b)} , {w.numpy()} , {b.numpy()}")
# Out:
# WARNING:tensorflow:From /Users/panhong/miniforge3/envs/tf_2_3/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1297: start (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.start` instead.

# %%
import tensorflow as tf

data = [[2,0,8] , [4,4,93] , [6,2,91] , [8,3,97]]
x1 = [x_row1[0] for x_row1 in data] 
x2 = [x_row2[1] for x_row2 in data] 
y_data = [y_row2[2] for y_row2 in data] 

a1 = tf.Variable(tf.random.uniform([1] , 0 ,10 , dtype = tf.float64 , seed = 0))
a2 = tf.Variable(tf.random.uniform([1] , 0 ,10 , dtype = tf.float64 , seed = 0))
b = tf.Variable(tf.random.uniform([1] , 0 ,100 , dtype = tf.float64 , seed = 0))

def hypothesis(a1 , a2 , b):
    return x1 * a1 + x2 * a2 + b

def costFunc():
    return tf.sqrt(tf.reduce_mean(tf.square(hypothesis(a1,a2,b) - y_data)))

def cost(a1 , a2 , b):
    return tf.sqrt(tf.reduce_mean(tf.square(hypothesis(a1,a2,b) - y_data)))

opt = tf.keras.optimizers.SGD(learning_rate = 0.1)

for i in range(6000):
    opt.minimize(costFunc , var_list = [a1, a2 , b])
    if i % 100 == 0:
        print(i , f"{cost(a1 , a2 , b)} , {a1.numpy()} , {a2.numpy()} , {b.numpy()}")
# Out:
# 0 15.679981522688902 , [8.0116387] , [7.88163848] , [18.50339989]
# 100 12.493097872135234 , [6.15669282] , [12.54914963] , [16.17992672]
# 200 11.51619332322718 , [5.65191676] , [14.51614771] , [13.87903026]
# 300 11.014782103716453 , [5.68206794] , [15.23310579] , [11.76921246]
# 400 10.64388833021966 , [5.87346737] , [15.51443962] , [9.87538154]
# 500 10.354234741878349 , [6.09392268] , [15.65277885] , [8.19416915]
# 600 10.130431017061271 , [6.30244107] , [15.74200581] , [6.71607993]
# 700 9.960323463306542 , [6.48829564] , [15.81078289] , [5.42759957]
# 800 9.83286536340636 , [6.65025306] , [15.8678998] , [4.3123778]
# 900 9.738454304449053 , [6.7899184] , [15.9164272] , [3.35261713]
# 1000 9.669143640814362 , [6.90965343] , [15.95784498] , [2.53031224]
# 1100 9.618604672910488 , [7.01191146] , [15.9931711] , [1.82815853]
# 1200 9.58194037951112 , [7.0990114] , [16.02324932] , [1.23011835]
# 1300 9.555441590599987 , [7.17305849] , [16.04881722] , [0.72170835]
# 1400 9.53634258523812 , [7.23592169] , [16.07052273] , [0.29008908]
